# %% [markdown]
# # Qualitative Evaluation
# ## Ausgangslage
# * Es sollen Kantonsratsprotokolle mit grosso-modo zeitgenössischer Sprache (ab 1950) klassifiziert werden
# * Bevor ein eigenes NER-Modell trainiert oder ein bestehendes verfeinert werden soll, sind bestehende Modelle out-of-the-box zu evaluieren
# * In Frage kommen grundsätzlich fertige Frameworks (vorzuziehen), gefolgt von HF-Modellen mit vortrainiertem NER-Head und HF-Modelle ohne NER-Head
# * Im Folgenden wird ein informeller Test an drei Dokumenten ausgeführt, d.h. noch ohne Goldstandardannotation.
#     * Die NEs werden innerhalb des Textes visualisiert und bezüglich Label und Type ausgezählt (dieses Notebook)
#     * Laufzeiten pro Dokument werden gemessen (allesamt auf lokaler Apple Mx MPS-GPU)
#     * Die Resultate werden zwischen den Modellen gedifft (Schlüsse dieses Notebook unten)
# * Zunächst werden Dokumente aus einem Jahr (1995) evaluiert. Die gesampelten Dokumente weisen unterschiedliche Längen auf, was die Skalierungsfähigkeit der Modelle testet.
#
# ## Hypothesen
# Es werden folgende vortrainierten NER-Modelle evaluiert, die aufgrund einer Bereitstellung als Framework oder durch vortrainierte NER-Heads direkt anwendbar sind. Dies ist eine pragmatische Entscheidung.
#
# * spaCy: Anwendungstaugliches NLP-Framework mit sehr guter Dokumentation, Support, usw.
#     * Textchunking integriert
#     * de_core_news_md, de_core_news_lg: grösste spaCy-Modelle (de_dep_news_trf hat out-of-the-box keine NER)
# * HF ZurichNLP/swissbert-ner: NER, das auf Schweizer Medientexten basiert und cross-linguale Bezüge ausnützt: Annahme, dass dies zumindest teilweise auf Schweiz-spezifische Dokumente anderer Domänen übertragbar ist, bzw. dass der Schweiz-spezifische Vorteil bis zu einem gewissen Grad erhalten bleibt
# * HF SpanMarker: 2022 SOTA, bietet diverse dt. Modelle
#     * stefan-it/span-marker-gelectra-large-germeval14
#     * gwlms/span-marker-teams-germeval14
#     * gwlms/span-marker-bert-germeval14
#     * gwlms/span-marker-token-dropping-bert-germeval14
# * flairNLP: Alternative zu spaCy, NLP-Framework mit div. dt. NER-Modellen
#
# ## Vorgehensweise
# * Per Sampling via Train-Test-Split (fixer Seed) selektierte Dokumente:
#   * KRP/KRP_1898-1995/MM_24_142/MM_24_142_KRP_1995_223_0003.xml
#   * KRP/KRP_1898-1995/MM_24_142/MM_24_142_KRP_1995_227_0003.xml
#   * KRP/KRP_1898-1995/MM_24_142/MM_24_142_KRP_1995_231_0009_MM_24_142_KRP_1995_231_0010.xml

# %%
import json
import time
import xml.etree.ElementTree as ET
from collections import Counter, defaultdict
from datetime import datetime

import flair
import spacy
import torch
from bs4 import BeautifulSoup
from flair.data import Sentence
from flair.models import SequenceTagger
from IPython.display import Markdown, display
from langchain.text_splitter import SpacyTextSplitter
from spacy import displacy
from spacy.tokens import Doc
from staatsarchiv_utils import generic_text_cleaning
from tqdm.notebook import tqdm
from transformers import pipeline

spacy.require_gpu()
mps_device = torch.device("mps")
flair.device = "mps:0"


def get_ent_json(doc):
    """Produce string with pseudo-tags for NEs that can be easily diffed."""
    doc_json = doc.to_json()
    for ent in doc_json["ents"][::-1]:
        doc_json["text"] = (
            doc_json["text"][: ent["start"]]
            + r"{{{}|{}}}".format(
                doc_json["text"][ent["start"] : ent["end"]], ent["label"]
            )
            + doc_json["text"][ent["end"] :]
        )
    return doc_json["text"]

# %% [markdown]
# # Installation spaCy-Modelle

# %%
# !python -m spacy download de_core_news_md
# !python -m spacy download de_core_news_lg
# !python -m spacy download de_dep_news_trf

# %% [markdown]
# # Modellinstanziierung

# %% [markdown]
# ## Modelle mit spaCy-Integration

# %%
sm_gelectra = spacy.load("de_dep_news_trf", exclude=["ner"])
sm_gelectra.add_pipe(
    "span_marker",
    config={
        "model": "stefan-it/span-marker-gelectra-large-germeval14",
        "device": "mps",
    },
)
print(sm_gelectra.pipe_names)

sm_teams = spacy.load("de_dep_news_trf", exclude=["ner"])
sm_teams.add_pipe(
    "span_marker",
    config={"model": "gwlms/span-marker-teams-germeval14", "device": "mps"},
)

sm_bert = spacy.load("de_dep_news_trf", exclude=["ner"])
sm_bert.add_pipe(
    "span_marker",
    config={"model": "gwlms/span-marker-bert-germeval14", "device": "mps"},
)

sm_td_bert = spacy.load("de_dep_news_trf", exclude=["ner"])
sm_td_bert.add_pipe(
    "span_marker",
    config={
        "model": "gwlms/span-marker-token-dropping-bert-germeval14",
        "device": "mps",
    },
)

spacy_integrated_models = {
    "de_core_news_md": spacy.load("de_core_news_md"),
    "de_core_news_lg": spacy.load("de_core_news_lg"),
    "sm_gelectra": sm_gelectra,
    "sm_teams": sm_teams,
    "sm_bert": sm_bert,
    "sm_td_bert": sm_td_bert,
}

# %% [markdown]
# ## Modelle ohne spaCy-Integration

# %%
# SwissBERT via transformers, as spaCy currently doesn't support X-MOD-based transformer heads
swissbert = pipeline(
    model="ZurichNLP/swissbert-ner", aggregation_strategy="simple", device="mps"
)

swissbert.model.set_default_language("de_CH")

fl_german_large = SequenceTagger.load("flair/ner-german-large")
# Out:
# 2024-04-26 20:41:54,270 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, B-PER, E-PER, S-LOC, B-MISC, I-MISC, E-MISC, S-PER, B-ORG, E-ORG, S-ORG, I-ORG, B-LOC, E-LOC, S-MISC, I-PER, I-LOC, <START>, <STOP>

# %% [markdown]
# # Plaintext aus XMLs extrahieren

# %%
texts = []

for doc in [
    "samples/MM_24_142_KRP_1995_223_0003.xml",
    "samples/MM_24_142_KRP_1995_227_0003.xml",
    "samples/MM_24_142_KRP_1995_231_0009_MM_24_142_KRP_1995_231_0010.xml",
]:
    tree = ET.parse(doc)
    root = tree.getroot()
    body = ET.tostring(
        root.findall(
            "./xmlns:text/xmlns:body",
            namespaces={"xmlns": "http://www.tei-c.org/ns/1.0"},
        )[0]
    )
    soup = BeautifulSoup(body)
    text = soup.find_all(string=True)
    text = " ".join([p.text for p in text])
    text = generic_text_cleaning(text)
    texts.append(text)

# %%
for text in texts:
    print(len(text.split()))
# Out:
# 2079
# 1757
# 10508

# %%
result_json_dict = defaultdict(list)
nlp_blank = spacy.blank("de")

# %% [markdown]
# # Anwendung spaCy-integrierter Modelle

# %%
docs = defaultdict(list)

# Process
for idx, text in tqdm(enumerate(texts)):
    predictions = []
    print("Document #{}".format(idx))
    for model_name, nlp in spacy_integrated_models.items():
        print(model_name)
        start = time.time()
        doc = nlp(text)
        doc.ents = [ent for ent in doc.ents if ent.label_ in {"PER", "LOC", "ORG"}]
        docs[model_name].append(doc)
        stop = time.time()
        duration = stop - start
        print("Time: {:.2f} sec".format(duration))
    print()

for model_name in docs:
    result_json_dict[model_name] = [get_ent_json(doc) for doc in docs[model_name]]
# Out:
# 0it [00:00, ?it/s]
# Document #0
# de_core_news_md
# Time: 0.45 sec
# de_core_news_lg
# Time: 0.43 sec
# sm_gelectra
# Time: 9.40 sec
# sm_teams
# Time: 4.36 sec
# sm_bert
# Time: 3.94 sec
# sm_td_bert
# Time: 4.09 sec
#
# Document #1
# de_core_news_md
# Time: 0.37 sec
# de_core_news_lg
# Time: 0.37 sec
# sm_gelectra
# Time: 7.44 sec
# sm_teams
# Time: 3.37 sec
# sm_bert
# Time: 3.53 sec
# sm_td_bert
# Time: 3.39 sec
#
# Document #2
# de_core_news_md
# Time: 2.31 sec
# de_core_news_lg
# Time: 2.30 sec
# sm_gelectra
# Time: 44.80 sec
# sm_teams
# Time: 20.12 sec
# sm_bert
# Time: 19.15 sec
# sm_td_bert
# Time: 18.78 sec

# %%
for model_name in docs:
    display(Markdown("# {}".format(model_name)))
    for idx, doc in enumerate(docs[model_name]):
        display(Markdown("## Doc #{}".format(idx)))
        print(
            sorted(
                Counter((ent.label_ for ent in doc.ents)).items(),
                key=lambda x: x[0],
                reverse=True,
            )
        )
        print(
            ", ".join(
                list(
                    map(
                        lambda x: "{}/{}".format(x[0], x[1]),
                        sorted(
                            Counter((ent.text for ent in doc.ents)).items(),
                            key=lambda x: x[1],
                            reverse=True,
                        ),
                    )
                )
            )
        )
        displacy.render(doc, style="ent", jupyter=True)
# Out:
# # de_core_news_md
# ## Doc #0
# [('PER', 26), ('ORG', 24), ('LOC', 28)]
# Einzelinitiative/9, Zürich/3, SP/3, EVP/3, SVP/3, Veröffentlichung/2, Dr. Hans-Jakob Mosimann/2, Winterthur/2, Franken/2, Blum/2, Puure-Zmorge/2, FDP/2, Mosimann/2, Troesch/2, Kantonalpartei/2, Fehr/2, anerkanntermassen/1, Woher/1, Raphael Huber/1, Wes Brot/1, Kantonalparteien/1, Martin Forster/1, Landesrings/1, Franziska Troesch-Schnyder/1, Zollikon/1, Staat/1, Peter Reinhard/1, Kloten/1, Esther Holm/1, Grüne/1, Horgen/1, Nachher/1, Herrn Reinhard/1, Kontenpläne/1, Hans Fehr/1, Eglisau/1, Kantonalpartei Komitees/1, Private/1, Lucius Dürr/1, CVP/1, Spass/1, Hartmuth Attenhofer/1, Sozialdemokraten/1, Hotel International/1, Zürich-Oerlikon/1, Hotels International/1, Herr Dürr/1, Gottlob/1, Blocher/1, Frey/1, Ratsmitgliedern/1
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Die
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Einzelinitiative
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#

#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  auf die Verlegung in die vollbelegte Strafanstalt warten müssen. Das trägt massgeblich zur Überbelegung der Bezirksgefängnisse bei. Verschiedene betriebliche und sicherheitstechnische Überlegungen haben zur Ausarbeitung eines Projekts für die Schaffung einer zusätzlichen Abteilung mit zweimal 30 Plätzen Anlass gegeben. Der Sicherheitsstandard wurde so festgelegt, dass er demjenigen der geschlossenen Abteilungen entspricht, und die wegen der begrenzten Kapazität der Werkstätten ohnehin erforderliche Unterbringung von Arbeitsräumen in der Abteilung selbst erlaubt die gleiche Art des Betriebs wie in jenen Abteilungen, die bereits heute im Gefängnis bestehen. Das Projekt der Erweiterung zeigt sich in der Situation so, dass ein eigenständiger Bau innerhalb der Umfassungsmauer gelegt werden soll und damit das Raumprogramm für 60 zusätzliche Plätze realisiert werden kann. Die Kosten des Projekts belaufen sich auf total 16,1 Millionen Franken. Es darf, wie bei diesen Gefängnisbauten üblich, ein Anteil des
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bundes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in der Grössenordnung von 40% bis 50% erwartet werden. Der Regierungsrat kommt in seinen Weisungen zum folgenden Schluss: Mit der beantragten Erweiterung der Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  um eine Abteilung mit 60 Plätzen wird deren Aufnahmekapazität um rund 20% erhöht, was zu einer erheblichen Entlastung der Bezirksgefängnisse führt, weil sich die Wartezeit für den Eintritt in die Strafanstalt verkürzt. Gleichzeitig wird damit erreicht, dass die neue Strafanstalt über bessere Möglichkeiten für die Unterbringung des seit ihrer Planung angestiegenen Anteils an
# # de_core_news_lg
# ## Doc #0
# [('PER', 25), ('ORG', 20), ('LOC', 22)]
# Zürich/3, SP/3, Franken/3, Einzelinitiative/3, EVP/3, SVP/3, Dr. Hans-Jakob Mosimann/2, Winterthur/2, Puure-Zmorge/2, FDP/2, Veröffentlichung/1, anerkanntermassen/1, Raphael Huber/1, Wes Brot/1, Vorstosses/1, Martin Forster/1, Franziska Troesch-Schnyder/1, Zollikon/1, Hauseigentümerverbände/1, Peter Reinhard/1, Kloten/1, Esther Holm/1, Grüne/1, Horgen/1, Einzelinitiative Blum/1, Herr Mosimann/1, Frau Troesch/1, Nachher/1, Herrn Reinhard/1, Hans Fehr/1, Eglisau/1, Mosimann/1, Blum/1, Troesch/1, Kantonalpartei Komitees/1, Lucius Dürr/1, CVP/1, Alfred Escher-Strasse/1, Spass/1, Hartmuth Attenhofer/1, Sozialdemokraten/1, Hotel International/1, Zürich-Oerlikon/1, Saal rammelvoll/1, Hotels International/1, Herr Dürr/1, Gottlob/1, Fehr/1, Herr Fehr/1, Blocher/1, Dr. Janos Blum/1
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Die Einzelinitiative lautet wie folgt: Es ist ein Gesetz zu erlassen, welches die im Kantonsrat vertretenen politischen Parteien verpflichtet, jährlich ihre Rechnung und Bilanz zu veröffentlichen. Die
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Veröffentlichung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  umfasst Einnahmen und Ausgaben, welche den ordentlichen Betrieb, die Öffentlichkeitsarbeit sowie Wahlen und Abstimmungen auf allen Ebenen (Kanton, Bezirk, Gemeinde, Kreis) betreffen. Die Begründung lautet wie folgt: Die Aufwendungen für Abstimmungen und Wahlkämpfe, vorab im Raum
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , sind in den letzten Jahren merklich gestiegen. Da die Parteien im politischen Meinungsbildungsprozess eine zentrale Rolle spielen, besteht ein klares öffentliches Interesse an der Offenlegung ihrer Finanzen.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dr. Hans-Jakob Mosimann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Winterthur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
/1, Dietikon/1, Dorothée Fierz/1, Egg/1, Weinland/1, Alt-Pfäffikon/1, Kaspar Günthardt/1, Dällikon/1, Südafrika/1, Robert Rietiker/1, Maur/1, Susanne Frutig/1, Sozialdemokratisch-Gewerkschaftliche Fraktion/1, Pfäffikon/1, Willy/1, Peter Aisslinger/1, Günthardt/1, Fierz/1, Gut/1, Frutig/1, Bern/1, Werner Scherrer/1, Uster/1, Anjuska Weil/1, Zürichs/1, Jugoslawien/1, Sri Lanka/1, Algerien/1, Europa/1, Bälde/1, Waid/1, EMRK/1, Martin Mossdorf/1, Bülach/1, Laurenz Styger/1, Erhard Bernet/1, FPS/1, Tages-Anzeiger/1, Universität Freiburg/1, Bundesrates/1, Moritz Leuenberger/1, Indessen/1, Fehr/1, Ernst Homberger/1, Weil/1
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Dr.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rudolf Jeker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FDP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ), Präsident der vorberatenden Kommission: Wir behandeln den Antrag des Regierungsrates 3421, Beschluss des Kantonsrates betreffend die Bewilligung eines Kredits für die Erweiterung der Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , um eine geschlossene Abteilung mit 60 Plätzen; hier wird ein Kredit von 16,1 Millionen Franken zur Bewilligung beantragt. Der zweite Antrag, 3428, betrifft den Antrag für die Bewilligung eines Kredits von 19,7 Millionen Franken für den Bau eines zweiten Ausschaffungsgefängnisses in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kloten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Die allgemeine Situation im zürcherischen Gefängniswesen darf mindestens wie sie in der Presse dargestellt und in der Bevölkerung auch wahrgenommen wird als bekannt vorausgesetzt werden. Ich werde mich deshalb kurz fassen und in einem ersten Teil meiner Ausführungen die Lagebeurteilung des Regierungsrates gemäss den Weisungen gerafft wiedergeben, um dann in einem zweiten Teil auf die Kommissionsberatungen einzugehen. Vorlage 3421 (Erweiterung der Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) Das Konzept für die neue Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , die im Frühling 1995 bezogen wurde, beruht in seinen Grundzügen auf den Feststellungen der in den Jahren 1972 bis 1976 tätigen Planungskommission. Während sowohl in betrieblicher Hinsicht, wie bei der Ausrüstung, insbesondere die Sicherheitsvorkehren, im Rahmen der weiteren Bearbeitung des aus dem Jahr 1980 stammenden Wettbewerbsprojekts stammten, ist die Bauausführung verschiedentlich der Situation angepasst worden. Die Kapazität umfasst heute rund 350 Plätze. Wie es sich gezeigt hat, ist diese Anzahl der zur Verfügung stehenden Plätze zu knapp. Insbesondere der Anstieg des Bestandes an ausländischen Strafgefangenen, die wegen Fluchtgefahr in geschlossenen Anstalten unterzubringen sind, aber auch die Zunahme von längeren Strafen haben dazu geführt, dass in letzter Zeit immer zwischen 50 und 100 Verurteilte in Bezirksgefängnissen auf die Verlegung in die vollbelegte Strafanstalt warten müssen. Das trägt massgeblich zur Überbelegung der Bezirksgefängnisse bei. Verschiedene betriebliche und sicherheitstechnische Überlegungen haben zur Ausarbeitung eines Projekts für die Schaffung einer zusätzlichen Abteilung mit zweimal 30 Plätzen Anlass gegeben. Der Sicherheitsstandard wurde so festgelegt, dass er demjenigen der geschlossenen Abteilungen entspricht, und die wegen der begrenzten Kapazität der Werkstätten ohnehin erforderliche Unterbringung von Arbeitsräumen in der Abteilung selbst erlaubt die gleiche Art des Betriebs wie in jenen Abteilungen, die bereits heute im Gefängnis bestehen. Das Projekt der Erweiterung zeigt sich in der Situation so, dass ein eigenständiger Bau innerhalb der Umfassungsmauer gelegt werden soll und damit das Raumprogramm für 60 zusätzliche Plätze realisiert werden kann. Die Kosten des Projekts belaufen sich auf total 16,1 Millionen Franken. Es darf, wie bei diesen Gefängnisbauten üblich, ein Anteil des Bundes in der Grössenordnung von 40% bis 50% erwartet werden. Der Regierungsrat kommt in seinen Weisungen zum folgenden Schluss: Mit der beantragten Erweiterung der Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  um eine Abteilung mit 60 Plätzen wird deren Aufnahmekapazität um rund 20% erhöht, was zu einer erheblichen Entlastung der Bezirksgefängnisse führt, weil sich die Wartezeit für den Eintritt in die Strafanstalt verkürzt. Gleichzeitig wird damit erreicht, dass die neue Strafanstalt über bessere Möglichkeiten für die Unterbringung des seit ihrer Planung angestiegenen Anteils an Gefangenen mit längeren Strafen und für die Aufteilung von Gefangenengruppen gleicher Nationalität oder ethischer Herkunft verfügt. Vorlage 3428 (zweites Ausschaffungsgefängnis in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kloten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) Das neue Bundesrecht: Mit dem in der Abstimmung vom Dezember angenommenen Bundesgesetz über Zwangsmassnahmen werden den rechtsanwendenden Behörden teils neue, teils bestehende, aber verschärfte Eingriffsmittel zur Verfügung gestellt. Sie sollen sicherstellen, dass weggewiesene Ausländer auch tatsächlich ausreisen; denn wie der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bundesrat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  zu den neuen Bestimmungen festgehalten hat der konsequente Wegweisungsvollzug von Ausländern, die in der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schweiz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-ali

# %% [markdown]
# # Anwendung von Modellen ohne spaCy-Integration

# %% [markdown]
# Einschränkungen: Erkannte NE-Spans werden einem spaCy-Dokument zugeordnet, um hier ebenfalls die displaCy-Visualisierung nutzen zu können. Spans, die sich aufgr. Tokenisierungunterschieden nicht zuordnen lassen, werden gesondert ausgegeben. SpacyTextSplitter kann Chunks produzieren, welche die Maximallänge des Modells übersteigen.

# %% [markdown]
# ## SwissBERT

# %%
# Instantiating text splitter from SwissBert tokenizer
text_splitter = SpacyTextSplitter.from_huggingface_tokenizer(
    swissbert.tokenizer,
    separator=" ",
    chunk_size=256,
    chunk_overlap=0,
    pipeline="de_core_news_lg",
)
# Process
for idx, text in enumerate(texts):
    start = time.time()
    display(Markdown("## Doc #{}".format(idx)))

    # Split text into segments
    segments = text_splitter.split_text(text)

    # Add linebreaks for readability
    segments = [segment + "\n\n" for segment in segments]

    seg_docs = []

    # Extract entities per segment
    for segment in segments:
        # Extract entities
        result = swissbert(segment)

        for entity in result:
            entity["label"] = entity.pop("entity_group")

        annotations = [
            entity for entity in result if entity["label"] in {"PER", "ORG", "LOC"}
        ]

        # Create spaCy document
        seg_doc = nlp_blank(segment)
        ents = []

        # Filter NEs and handle mapping of span annotations to spaCy token-level annotations
        for annotation in annotations:
            if annotation["label"] not in {"PER", "LOC", "ORG"}:
                continue
            span = seg_doc.char_span(
                annotation["start"] + 1, annotation["end"], label=annotation["label"]
            )
            if span is None:
                span = seg_doc.char_span(
                    annotation["start"], annotation["end"], label=annotation["label"]
                )
            if span is not None:
                ents.append(span)
            else:
                print("Span error:", annotation)

        seg_doc.ents = spacy.util.filter_spans(ents)
        seg_docs.append(seg_doc)

    # Combine per-segment spaCy documents
    doc = Doc.from_docs(seg_docs)
    result_json_dict["swissbert"].append(get_ent_json(doc))
    stop = time.time()
    duration = stop - start

    # Visualize
    print(
        sorted(
            Counter((ent.label_ for ent in doc.ents)).items(),
            key=lambda x: x[0],
            reverse=True,
        )
    )

    print(
        ", ".join(
            list(
                map(
                    lambda x: "{}/{}".format(x[0], x[1]),
                    sorted(
                        Counter((ent.text for ent in doc.ents)).items(),
                        key=lambda x: x[1],
                        reverse=True,
                    ),
                )
            )
        )
    )
    print()
    print("Time: {:.2f} sec".format(duration))
    displacy.render(doc, style="ent", jupyter=True)
# Out:
# ## Doc #0
# Span error: {'score': 0.99968004, 'word': 'Hart', 'start': 643, 'end': 648, 'label': 'PER'}
# Span error: {'score': 0.9987632, 'word': 'mut', 'start': 648, 'end': 651, 'label': 'PER'}
# Span error: {'score': 0.959829, 'word': 'h Attenhofer', 'start': 651, 'end': 663, 'label': 'PER'}
# Span error: {'score': 0.72949684, 'word': '.', 'start': 898, 'end': 899, 'label': 'PER'}
# [('PER', 19), ('ORG', 11), ('LOC', 13)]
# Zürich/3, SP/3, EVP/3, Hans-Jakob Mosimann/2, Winterthur/2, FDP/2, Frau Troesch/2, SVP/2, Blum/1, Raphael Huber/1, Martin Forster/1, Franziska Troesch-Schnyder/1, Zollikon/1, Peter Reinhard/1, Kloten/1, Esther Holm/1, Horgen/1, Mosimann/1, Reinhard/1, Hans Fehr/1, Eglisau/1, Lucius Dürr/1, CVP/1, Alfred Escher-Strasse/1, Hotel International/1, Zürich-Oerlikon/1, Hotels International/1, Herr Fehr/1, Fehr/1, Herr Blocher/1, Herr Frey/1, Janos Blum/1
#
# Time: 3.41 sec
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Die Einzelinitiative lautet wie folgt: Es ist ein Gesetz zu erlassen, welches die im Kantonsrat vertretenen politischen Parteien verpflichtet, jährlich ihre Rechnung und Bilanz zu veröffentlichen. Die Veröffentlichung umfasst Einnahmen und Ausgaben, welche den ordentlichen Betrieb, die Öffentlichkeitsarbeit sowie Wahlen und Abstimmungen auf allen Ebenen (Kanton, Bezirk, Gemeinde, Kreis) betreffen. Die Begründung lautet wie folgt: Die Aufwendungen für Abstimmungen und Wahlkämpfe, vorab im Raum
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , sind in den letzten Jahren merklich gestiegen. Da die Parteien im politischen Meinungsbildungsprozess eine zentrale Rolle spielen, besteht ein klares öffentliches Interesse an der Offenlegung ihrer Finanzen. Dr.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hans-Jakob Mosimann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Winterthur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ): Politik ist definitions- und aufgabengemäss eine öffentliche Angelegenheit. Was für die Fische das Wasser, ist für die politischen Parteien die Öffentlichkeitsarbeit: Sie sind auf dieses Medium existentiell angewiesen, und sauberes Wasser ist anerkanntermassen das gesündere. Nun ist Politik aber alles andere als gratis.<br><br>Parteien bewegen jährlich Hunderttausende, manchmal Millionen von Franken. Woher stammt dieses Geld? Auf diese Frage verlieren einige Parteien schlagartig das Interesse an der Öffentlichkeit. Für sie ist die Finanzierung der Politik nicht etwa eine Grauzone, sondern idealerweise eine fugendichte Dunkelkammer. Hier möchte die Einzelinitiative
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  für etwas mehr Beleuchtung sorgen: Transparenz und klare Verhältnisse sind für unsere Demokratie etwas Wesentliches. Darum besteht ein öffentliches Interesse an den Parteifinanzen. Ein NZZ -Redaktor publizierte vor zwei Monaten unter dem Titel Korruption in der Schweiz Überlegungen zum Fall
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raphael Huber
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Zur Frage der Parteienfinanzierung befand er dabei, die Sauberkeit liesse sich mit einer Offenlegung der Finanzen, sogar freiwillig, verbessern. Es geht letztlich um die Vermutung, dass, wer zahlt, auch befiehlt. Stimmt diese Vermutung, ist eine Offenlegung dringend nötig. Stimmt sie nicht, gibt es auch nichts zu verbergen die Offenlegung wäre dann gerade der Tatbeweis gegen die dann eben falsche These.<br><br>So oder so hat die Öffentlichkeit ein Recht zu wissen, woher das manchmal grosse Geld in der Politik stammt. Sport wird ja auch viel gespendet. Aber dort tragen die Sportler die entsprechenden Leibchen und Hütchen, sogar je sichtbarer, desto besser. Es ist zum Beispiel nicht unwesentlich zu erfahren, wer das Geld liefert für die unzähligen Puure-Zmorge und ähnliche politisch vielseitige Anlässe, inklusive den dafür erscheinenden Inseraten. An diesem Beispiel lässt sich auch zeigen, was der Vorstoss nicht will: Es geht nicht um die vielen einzelnen kleinen Beträge, die überall zusammenkommen. Es geht um die grösseren Brocken, zum Beispiel über 1000 Franken für Personen, über 10 000 Franken bei Firmen. diesen Grössenordnungen soll die Öffentlichkeit beurteilen können, ob es nach dem Motto Wes Brot ich ess’, des Lied ich sing’ geht oder nicht. Man braucht mir als langjährigem Parteipräsidenten auch nicht zu sagen, es sei nicht praktikabel, weil die Kantonalparteien intern vielfältig gegliedert seien.<br><br>Für ein funktionierendes Parteimanagement ist im PC-Zeitalter eine konsolidierte Rechnungslegung nun wirklich kein Problem. Ich bitte Sie deshalb abschliessend, die grundsätzlichen Aspekte des Vorstosses angemessen zu würdigen. Zu Fragen der Ausgestaltung und der praktischen Handhabung können wir uns noch immer ausgiebig äussern aber nur, wenn Sie jetzt die Einzelinitiative vorläufig unterstützen. Dies sollte nicht allen gleich schwer fallen. So hat sich 1987 der Sprecher der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  dafür ausgesprochen, die ganze Problematik der Offenlegung der Parteienfinanzierung näher zu prüfen Und Herr
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Martin Forster
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sagte damals: Die Offenlegung der Parteifinanzierung entspricht einem alten Anliegen des Landesrings Auch der Regierungsrat hat sich dazu geäussert. Er befand, es lasse sich ein gewisses öffentliches Interesse an der Kenntnis der Finanzquellen, über welche die Parteien verfügen, nicht verneinen Ich danke Ihnen für die vorläufige Unterstützung.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Franziska Troesch-Schnyder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FDP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zollikon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ): Bereits früher sind ähnliche Vorstösse, allerdings ergänzt durch die Forderung nach staatlicher Parteienfinanzierung, abgelehnt worden.<br><br>Namen der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FDP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  bitte ich Sie, auch diese Einzelinitiative nicht zu unterstützen
# ## Doc #1
# Span error: {'score': 0.5028198, 'word': 'Patron', 'start': 484, 'end': 491, 'label': 'PER'}
# Span error: {'score': 0.99950397, 'word': '', 'start': 690, 'end': 691, 'label': 'PER'}
# Span error: {'score': 0.6675605, 'word': 'Zuppig', 'start': 969, 'end': 976, 'label': 'PER'}
# [('PER', 9), ('ORG', 7), ('LOC', 33)]
# Kanton Zürich/7, SVP/4, Luzern/3, Zürich/3, Schwyz/2, Zug/2, Dietikon/2, Kantons Zürich/1, Uri/1, Obwalden/1, Nidwalden/1, Wallis/1, Kanton Schaffhausen/1, Remo Patroni/1, Uster/1, Karl Epting/1, Thomas Büchi/1, Grüne/1, Kanton Graubünden/1, Ulrich Schäpper/1, SP/1, Schweiz/1, Bruno Kuhn/1, Lindau/1, Kanton Schwyz/1, Regula Pfister/1, FDP/1, Innerschweizer/1, Bruno Zuppiger/1, Hinwil/1, Schaffhausen/1, Germain Mittaz/1, Hans Wiederkehr/1
#
# Time: 1.85 sec
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Die Einzelinitiative lautet wie folgt: Es sei die Steuergesetzgebung des
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kantons Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  so zu ändern, dass auf Erbanfällen und Schenkungen von Eltern an Kinder keine Erbschafts- bzw. Schenkungssteuer mehr erhoben wird. Die Begründung lautet wie folgt: Zahlreiche Kantone besteuern Erbanfälle und Schenkungen von Eltern an Kinder nicht. Zu ihnen gehören die Kantone
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Luzern
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Uri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schwyz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obwalden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nidwalden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wallis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  und seit einiger zeit Zeit auch der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton Schaffhausen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ist lediglich ein Erbanfall bis Fr. 100 000 steuerfrei. Diese Gesetzgebung hat dazu geführt, dass immer mehr wohlhabende Steuerpflichtige ihren Wohnsitz in einen Kanton verlegen, wo sie den Nachlass ihren Nachkommen steuerfrei vererben und steuerfreie Schenkungen vornehmen können. Es ist bekannt, dass zahlreiche prominente Persönlichkeiten deswegen ihren Wohnsitz im
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  aufgegeben haben. Die Nachteile liegen auf der Hand: Steuern auf Vermögen, Vermögenserträgen und Arbeitseinkommen fallen im
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  weg. Dies dürfte einen erheblichen Steuerausfall ausmachen.<br><br>Es kommt dazu, dass zu Lebzeiten eines Erblassers oder eines Schenkenden auf dessen Vermögen die Vermögenssteuer und auf Einkommen die Einkommenssteuer erhoben wurde. Es gibt deshalb kaum eine Rechtfertigung dafür, die Vermögensmasse bei Vererbung oder bei Schenkung an die Nachkommen mit der Erbschafts- oder Schenkungssteuer zu belasten. Besonders ungünstig sind Liegenschaftenbesitzer gestellt: Liegenschaften werden bei Erbgang oder Schenkung zum Verkehrswert besteuert und unterliegen bei einem späteren Verkauf überdies noch der Grundstückgewinnsteuer. Ich bitte Sie daher, meine Einzelinitiative zu unterstützen.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Remo Patroni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (FPS,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Uster
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ): Die FPS unterstützt die Einzelinitiative von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karl Epting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Folgende Gründung sprechen dafür: Etliche Kantone kennen die Erbschafts- und Schenkungssteuer im Verhältnis Eltern–Kinder nicht. Es sind Steueroasen, die auch ausgenützt werden. Steuerpflicht bringt Steuerausfall. unserem Kanton können dies erhebliche Beträge sein.<br><br>Bekanntlich entrichtet ein Erblasser zu Lebzeiten Einkommens- und Vermögenssteuer. Die Erbmasse über 100 000 Franken nochmals mit einer Steuer zu belasten, ist ungerechtfertigt. Bei Erbgang oder Schenkung werden Liegenschaften zum Verkehrswert besteuert und unterliegen bei einem späteren Verkauf der Grundstückgewinnsteuer. Dies ist ein weiterer Grund, der gegen die jetzige Erbschaftssteuerpraxis spricht. Ich bitte die bürgerlichen Ratskolleginnen und Ratskollegen, die Einzelinitiative vorläufig zu unterstützen.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thomas Büchi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grüne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ): Ich bitte Sie, die Einzelinitiative nicht vorläufig zu unterstützen, und zwar aus folgenden Gründen. An erster Stelle steht sicher noch über ein paar Jahre hinaus die finanzielle Lage des Staates. Eine Kürzung der Einkünfte würde einfach bedeuten, bei der Einkommens- und Vermögenssteuer kompensieren zu müssen. Aber es g
# ## Doc #2
# Span error: {'score': 0.99044925, 'word': '', 'start': 1103, 'end': 1104, 'label': 'ORG'}
# Span error: {'score': 0.6491486, 'word': 'Sozialdemokrat', 'start': 529, 'end': 544, 'label': 'ORG'}
# Span error: {'score': 0.9996055, 'word': '', 'start': 527, 'end': 528, 'label': 'PER'}
# Span error: {'score': 0.6183646, 'word': 'P', 'start': 461, 'end': 463, 'label': 'LOC'}
# Span error: {'score': 0.40637845, 'word': 'öschwies', 'start': 463, 'end': 471, 'label': 'LOC'}
# Span error: {'score': 0.99964833, 'word': 'Do', 'start': 964, 'end': 967, 'label': 'PER'}
# Span error: {'score': 0.9986627, 'word': 'roth', 'start': 967, 'end': 971, 'label': 'PER'}
# Span error: {'score': 0.9965439, 'word': 'ée Fierz', 'start': 971, 'end': 979, 'label': 'PER'}
# Span error: {'score': 0.6065748, 'word': 'Hol', 'start': 760, 'end': 764, 'label': 'PER'}
# Span error: {'score': 0.6500239, 'word': 'Kaserne', 'start': 417, 'end': 425, 'label': 'LOC'}
# Span error: {'score': 0.48783496, 'word': 'Riet', 'start': 628, 'end': 633, 'label': 'PER'}
# Span error: {'score': 0.99777466, 'word': 'P', 'start': 823, 'end': 825, 'label': 'LOC'}
# Span error: {'score': 0.98588467, 'word': 'öschwies', 'start': 825, 'end': 833, 'label': 'LOC'}
# Span error: {'score': 0.4007316, 'word': 'Günthard', 'start': 94, 'end': 103, 'label': 'PER'}
# Span error: {'score': 0.75946057, 'word': 'e Noah', 'start': 500, 'end': 506, 'label': 'LOC'}
# Span error: {'score': 0.5806607, 'word': 'e Noah', 'start': 568, 'end': 574, 'label': 'LOC'}
# Span error: {'score': 0.49826014, 'word': 'A', 'start': 155, 'end': 157, 'label': 'PER'}
# Span error: {'score': 0.7009817, 'word': 'ut', 'start': 503, 'end': 505, 'label': 'PER'}
# Span error: {'score': 0.8671102, 'word': 'P', 'start': 859, 'end': 861, 'label': 'LOC'}
# Span error: {'score': 0.3658625, 'word': 'öschwies', 'start': 861, 'end': 869, 'label': 'LOC'}
# Span error: {'score': 0.53103095, 'word': 'P', 'start': 104, 'end': 106, 'label': 'LOC'}
# Span error: {'score': 0.5251437, 'word': 'Homberg', 'start': 408, 'end': 416, 'label': 'PER'}
# Span error: {'score': 0.7891786, 'word': 'Moss', 'start': 435, 'end': 440, 'label': 'PER'}
# Span error: {'score': 0.9971449, 'word': 'Zürich', 'start': 189, 'end': 196, 'label': 'LOC'}
# Span error: {'score': 0.50712687, 'word': 'Homberg', 'start': 1002, 'end': 1010, 'label': 'PER'}
# Span error: {'score': 0.99968255, 'word': 'La', 'start': 234, 'end': 237, 'label': 'PER'}
# Span error: {'score': 0.9992912, 'word': 'ur', 'start': 237, 'end': 239, 'label': 'PER'}
# Span error: {'score': 0.99673235, 'word': 'enz Styger', 'start': 239, 'end': 249, 'label': 'PER'}
# Span error: {'score': 0.9478558, 'word': 'Neu', 'start': 406, 'end': 410, 'label': 'PER'}
# Span error: {'score': 0.99964476, 'word': 'Er', 'start': 0, 'end': 2, 'label': 'PER'}
# Span error: {'score': 0.998681, 'word': 'hard Bernet', 'start': 2, 'end': 13, 'label': 'PER'}
# Span error: {'score': 0.8608615, 'word': 'F', 'start': 15, 'end': 16, 'label': 'ORG'}
# Span error: {'score': 0.63143337, 'word': 'Riet', 'start': 20, 'end': 25, 'label': 'PER'}
# Span error: {'score': 0.7979794, 'word': 'Aiss', 'start': 295, 'end': 300, 'label': 'PER'}
# Span error: {'score': 0.99784017, 'word': 'P', 'start': 584, 'end': 586, 'label': 'LOC'}
# Span error: {'score': 0.7868928, 'word': 'öschwies', 'start': 586, 'end': 594, 'label': 'LOC'}
# Span error: {'score': 0.86494225, 'word': '', 'start': 889, 'end': 890, 'label': 'ORG'}
# [('PER', 36), ('ORG', 33), ('LOC', 146)]
# Zürich/21, Kloten/17, Strafanstalt Pöschwies/15, Regensdorf/12, Kanton Zürich/11, Pöschwies/11, Schweiz/10, Waid/7, Ausschaffungsgefängnis Kloten/6, SP/6, FDP/5, Willy Spieler/4, SVP/4, Rudolf Jeker/3, Mario Fehr/3, Anstalt Pöschwies/3, Schweizer Demokraten/3, EJPD/2, Küsnacht/2, Adliswil/2, Spieler/2, Dielsdorf/2, Daniel Vischer/2, Herr Spieler/2, Kantonsschule Bülach/2, EVP/2, Peter Grau/2, Strafanstalt Regensdorf/2, Robert Neukomm/2, Genf/1, Esther Holm/1, Horgen/1, Kantons Zürich/1, Fraktion/1, Rote Kreuz/1, Germain Mittaz/1, CVP/1, Dietikon/1, Egg/1, Weinland/1, Alt-Pfäffikon/1, Kaspar Günthardt/1, Dällikon/1, Südafrika/1, Robert Rietiker/1, Maur/1, Susanne Frutig/1, Pfäffikon/1, Peter Aisslinger/1, Bezirksgefängnis Zürich/1, Frau Holm/1, Herrn Gut/1, Bern/1, Leuenberger/1, Werner Scherrer/1, Uster/1, Vischer/1, Ex- Jugoslawien/1, Sri Lanka/1, Algerien/1, Notgefängnis Waid/1, EMRK/1, Martin Mossdorf/1, Bülach/1, Vollzugsanstalt Regensdorf/1, Bezirksgefängnisses Dielsdorf/1, Erweiterungsbau Pöschwies/1, Mossdorf/1, SD/1, Gefängnis Regensdorf/1, FraP!/1, Sozialethischen Instituts/1, grossen Landeskirchen/1, Vollzug/1, Universität Freiburg/1, Moritz Leuenberger/1, Vollzugsanstalt Pöschwies/1, Holm/1, Ernst Homberger/1
#
# Time: 8.24 sec
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Dr.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rudolf Jeker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FDP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ), Präsident der vorberatenden Kommission: Wir behandeln den Antrag des Regierungsrates 3421, Beschluss des Kantonsrates betreffend die Bewilligung eines Kredits für die Erweiterung der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strafanstalt Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , um eine geschlossene Abteilung mit 60 Plätzen; hier wird ein Kredit von 16,1 Millionen Franken zur Bewilligung beantragt. Der zweite Antrag, 3428, betrifft den Antrag für die Bewilligung eines Kredits von 19,7 Millionen Franken für den Bau eines zweiten Ausschaffungsgefängnisses in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kloten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Die allgemeine Situation im zürcherischen Gefängniswesen darf mindestens wie sie in der Presse dargestellt und in der Bevölkerung auch wahrgenommen wird als bekannt vorausgesetzt werden. Ich werde mich deshalb kurz fassen und in einem ersten Teil meiner Ausführungen die Lagebeurteilung des Regierungsrates gemäss den Weisungen gerafft wiedergeben, um dann in einem zweiten Teil auf die Kommissionsberatungen einzugehen. Vorlage 3421 (Erweiterung der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strafanstalt Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# )<br><br>Das Konzept für die neue
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strafanstalt Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , die im Frühling 1995 bezogen wurde, beruht in seinen Grundzügen auf den Feststellungen der in den Jahren 1972 bis 1976 tätigen Planungskommission. Während sowohl in betrieblicher Hinsicht, wie bei der Ausrüstung, insbesondere die Sicherheitsvorkehren, im Rahmen der weiteren Bearbeitung des aus dem Jahr 1980 stammenden Wettbewerbsprojekts stammten, ist die Bauausführung verschiedentlich der Situation angepasst worden. Die Kapazität umfasst heute rund 350 Plätze. Wie es sich gezeigt hat, ist diese Anzahl der zur Verfügung stehenden Plätze zu knapp. Insbesondere der Anstieg des Bestandes an ausländischen Strafgefangenen, die wegen Fluchtgefahr in geschlossenen Anstalten unterzubringen sind, aber auch die Zunahme von längeren Strafen haben dazu geführt, dass in letzter Zeit immer zwischen 50 und 100 Verurteilte in Bezirksgefängnissen auf die Verlegung in die vollbelegte Strafanstalt warten müssen. Das trägt massgeblich zur Überbelegung der Bezirksgefängnisse bei. Verschiedene betriebliche und sicherheitstechnische Überlegungen haben zur Ausarbeitung eines Projekts für die Schaffung einer zusätzlichen Abteilung mit zweimal 30 Plätzen Anlass gegeben.<br><br>Der Sicherheitsstandard wurde so festgelegt, dass er demjenigen der geschlossenen Abteilungen entspricht, und die wegen der begrenzten Kapazität der Werkstätten ohnehin erforderliche Unterbringung von Arbeitsräumen in der Abteilung selbst erlaubt die gleiche Art des Betriebs wie in jenen Abteilungen, die bereits heute im Gefängnis bestehen. Das Projekt der Erweiterung zeigt sich in der Situation so, dass ein eigenständiger Bau innerhalb der Umfassungsmauer gelegt werden soll und damit das Raumprogramm für 60 zusätzliche Plätze realisiert werden kann. Die Kosten des Projekts belaufen sich auf total 16,1 Millionen Franken. Es darf, wie bei diesen Gefängnisbauten üblich, ein Anteil des Bundes in der Grössenordnung von 40% bis 50% erwartet werden. Der Regierungsrat kommt in seinen Weisungen zum folgenden Schluss: Mit der beantragten Erweiterung der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strafanstalt Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  um eine Abteilung mit 60 Plätzen wird deren Aufnahmekapazität um rund 20% erhöht, was zu einer erheblichen Entlastung der Bezirksgefängnisse führt, weil sich die Wartezeit für den Eintritt in die Strafanstalt verkürzt.<br><br>Gleichzeitig wird damit erreicht, dass die neue Strafanstalt über bessere Möglichkeiten für die Unterbringung des seit ihrer Planung angestiegenen Anteils an Gefangenen mit längeren Strafen und für die Aufteilung von Gefangenengruppen gleicher Nationalität oder ethischer Herkunft verfügt. Vorlage 3428 (zweites Ausschaffungsgefängnis in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kloten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) Das neue Bundesrecht: Mit dem in der Abstimmung vom Dezember angenommenen Bundesgesetz über Zwangsmassnahmen werden den rechtsanwendenden Behörden teils neue, teils bestehende, aber verschärfte Eingriffsmittel zur Verfügung gestellt. Sie sollen sicherstellen, dass weggewiesene Ausländer auch tatsächlich ausreisen; denn wie der Bundesrat zu den neuen Bestimmungen festgehalten hat der konsequente Wegweisungsvollzug von Ausländern, die in der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schweiz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  keine Anwesenheitsbewilligung erhalten haben, stellt einen Grundpfeiler einer glaubwürdigen Asyl- und Ausländerpolitik dar. Unter den verschiedenen Eingriffsmitteln sind es zwei, die vorliegend besonders interessieren. D

# %% [markdown]
# ## Flair fl_german_large

# %%
# Instantiate text splitter using spaCy model
text_splitter = SpacyTextSplitter(
    separator=" ", chunk_size=256, chunk_overlap=0, pipeline="de_core_news_lg"
)

# Process
for idx, text in enumerate(texts):
    start = time.time()
    display(Markdown("## Doc #{}".format(idx)))

    # Split text into segments
    segments = text_splitter.split_text(text)

    # Add linebreaks for readability
    segments = [segment + "\n\n" for segment in segments]

    seg_docs = []

    # Extract entities per segment
    for segment in segments:
        result = Sentence(segment)
        fl_german_large.predict(result)

        # Map flairNLP entity to spaCy-compatible span dictionary
        annotations = [
            {
                "span": entity.text,
                "label": entity.tag,
                "score": entity.score,
                "start": entity.start_position,
                "end": entity.end_position,
            }
            for entity in result.get_spans("ner")
            if entity.tag in {"PER", "ORG", "LOC"}
        ]
        # Create spaCy document
        seg_doc = nlp_blank(segment)
        ents = []

        # Filter NEs and handle mapping of span annotations to spaCy token-level annotations
        for annotation in annotations:
            if annotation["label"] not in {"PER", "LOC", "ORG"}:
                continue
            span = seg_doc.char_span(
                annotation["start"] + 1, annotation["end"], label=annotation["label"]
            )
            if span is None:
                span = seg_doc.char_span(
                    annotation["start"], annotation["end"], label=annotation["label"]
                )
            if span is not None:
                ents.append(span)
            else:
                print("Span error:", annotation)

        seg_doc.ents = spacy.util.filter_spans(ents)
        seg_docs.append(seg_doc)

    # Combine per-segment spaCy documents
    doc = Doc.from_docs(seg_docs)
    result_json_dict["fl_german_large"].append(get_ent_json(doc))
    stop = time.time()
    duration = stop - start

    # Visualize
    print(
        sorted(
            Counter((ent.label_ for ent in doc.ents)).items(),
            key=lambda x: x[0],
            reverse=True,
        )
    )

    print(
        ", ".join(
            list(
                map(
                    lambda x: "{}/{}".format(x[0], x[1]),
                    sorted(
                        Counter((ent.text for ent in doc.ents)).items(),
                        key=lambda x: x[1],
                        reverse=True,
                    ),
                )
            )
        )
    )
    print()
    print("Time: {:.2f} sec".format(duration))
    displacy.render(doc, style="ent", jupyter=True)
# Out:
# ## Doc #0
# Created a chunk of size 271, which is longer than the specified 256
# Created a chunk of size 291, which is longer than the specified 256
# Created a chunk of size 290, which is longer than the specified 256
# [('PER', 24), ('ORG', 15), ('LOC', 13)]
# Blum/4, Zürich/3, SP/3, EVP/3, SVP/3, Hans-Jakob Mosimann/2, Winterthur/2, FDP/2, Mosimann/2, Troesch/2, Fehr/2, Schweiz/1, Raphael Huber/1, Martin Forster/1, Franziska Troesch-Schnyder/1, Zollikon/1, Peter Reinhard/1, Kloten/1, Esther Holm/1, Grüne/1, Horgen/1, Reinhard/1, Hans Fehr/1, Eglisau/1, Lucius Dürr/1, CVP/1, Alfred Escher-Strasse/1, Hartmuth Attenhofer/1, Hotel International/1, Zürich-Oerlikon/1, Hotels International/1, Dürr/1, Blocher/1, Frey/1, Janos Blum/1
#
# Time: 13.90 sec
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Die Einzelinitiative lautet wie folgt: Es ist ein Gesetz zu erlassen, welches die im Kantonsrat vertretenen politischen Parteien verpflichtet, jährlich ihre Rechnung und Bilanz zu veröffentlichen.<br><br>Die Veröffentlichung umfasst Einnahmen und Ausgaben, welche den ordentlichen Betrieb, die Öffentlichkeitsarbeit sowie Wahlen und Abstimmungen auf allen Ebenen (Kanton, Bezirk, Gemeinde, Kreis) betreffen. Die Begründung lautet wie folgt:<br><br>Die Aufwendungen für Abstimmungen und Wahlkämpfe, vorab im Raum
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , sind in den letzten Jahren merklich gestiegen.<br><br>Da die Parteien im politischen Meinungsbildungsprozess eine zentrale Rolle spielen, besteht ein klares öffentliches Interesse an der Offenlegung ihrer Finanzen. Dr.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hans-Jakob Mosimann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Winterthur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ):<br><br>Politik ist definitions- und aufgabengemäss eine öffentliche Angelegenheit. Was für die Fische das Wasser, ist für die politischen Parteien die Öffentlichkeitsarbeit:<br><br>Sie sind auf dieses Medium existentiell angewiesen, und sauberes Wasser ist anerkanntermassen das gesündere. Nun ist Politik aber alles andere als gratis. Parteien bewegen jährlich Hunderttausende, manchmal Millionen von Franken. Woher stammt dieses Geld?<br><br>Auf diese Frage verlieren einige Parteien schlagartig das Interesse an der Öffentlichkeit. Für sie ist die Finanzierung der Politik nicht etwa eine Grauzone, sondern idealerweise eine fugendichte Dunkelkammer.<br><br>Hier möchte die Einzelinitiative
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  für etwas mehr Beleuchtung sorgen: Transparenz und klare Verhältnisse sind für unsere Demokratie etwas Wesentliches. Darum besteht ein öffentliches Interesse an den Parteifinanzen.<br><br>Ein NZZ -Redaktor publizierte vor zwei Monaten unter dem Titel Korruption in der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schweiz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  Überlegungen zum Fall
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raphael Huber
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .<br><br>Zur Frage der Parteienfinanzierung befand er dabei, die Sauberkeit liesse sich mit einer Offenlegung der Finanzen, sogar freiwillig, verbessern. Es geht letztlich um die Vermutung, dass, wer zahlt, auch befiehlt.<br><br>Stimmt diese Vermutung, ist eine Offenlegung dringend nötig. Stimmt sie nicht, gibt es auch nichts zu verbergen die Offenlegung wäre dann gerade der Tatbeweis gegen die dann eben falsche These.<br><br>So oder so hat die Öffentlichkeit ein Recht zu wissen, woher das manchmal grosse Geld in der Politik stammt. Sport wird ja auch viel gespendet. Aber dort tragen die Sportler die entsprechenden Leibchen und Hütchen, sogar je sichtbarer, desto besser.<br><br>Es ist zum Beispiel nicht unwesentlich zu erfahren, wer das Geld liefert für die unzähligen Puure-Zmorge und ähnliche politisch vielseitige Anlässe, inklusive den dafür erscheinenden Inseraten.<br><br>An diesem Beispiel lässt sich auch zeigen, was der Vorstoss nicht will: Es geht nicht um die vielen einzelnen kleinen Beträge, die überall zusammenkommen.<br><br>Es geht um die grösseren Brocken, zum Beispiel über 1000 Franken für Personen, über 10 000 Franken bei Firmen. diesen Grössenordnungen soll die Öffentlichkeit beurteilen können, ob es nach dem Motto Wes Brot ich ess’, des Lied ich sing’ geht oder nicht.<br><br>Man braucht mir als langjährigem Parteipräsidenten auch nicht zu sagen, es sei nicht praktikabel, weil die Kantonalparteien intern vielfältig gegliedert seien.<br><br>Für ein funktionierendes Parteimanagement ist im PC-Zeitalter eine konsolidierte Rechnungslegung nun wirklich kein Problem. Ich bitte Sie deshalb abschliessend, die grundsätzlichen Aspekte des Vorstosses angemessen zu würdigen.<br><br>Zu Fragen der Ausgestaltung und der praktischen Handhabung können wir uns noch immer ausgiebig äussern aber nur, wenn Sie jetzt die Einzelinitiative vorläufig unterstützen. Dies sollte nicht allen gleich schwer fallen.<br><br>So hat sich 1987 der Sprecher der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  dafür ausgesprochen, die ganze Problematik der Offenlegung der Parteienfinanzierung näher zu prüfen<br><br>Und Herr
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Martin Forster
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sagte damals: Die Offenlegung der Parteifinanzierung entspricht einem alten Anliegen des Landesrings Auch der Regierungsrat hat sich dazu geäussert.<br><br>Er befand, es lasse sich ein gewisses öffentliches Interesse an der Kenntnis der Finanzquellen, über welche die Parteien verfügen, nicht verneinen Ich danke Ihnen für die vorläufige Unterstützung.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Franziska Troesch-Schnyder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FDP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zollikon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ):<br><br>Bereits früher sind ähnliche Vorstösse, allerdings ergänzt durch die Forderung nach staatlic
# ## Doc #1
# Created a chunk of size 257, which is longer than the specified 256
# Created a chunk of size 354, which is longer than the specified 256
# [('PER', 17), ('ORG', 13), ('LOC', 31)]
# Zürich/11, SVP/4, Luzern/3, Schwyz/3, Epting/3, Schaffhausen/2, Grüne/2, Patroni/2, Schäpper/2, Zug/2, Dietikon/2, Uri/1, Obwalden/1, Nidwalden/1, Wallis/1, Remo Patroni/1, FPS/1, Karl Epting/1, Thomas Büchi/1, Graubünden/1, Ulrich Schäpper/1, SP/1, SonntagsZeitung/1, Schweiz/1, Bruno Kuhn/1, Lindau/1, Regula Pfister/1, FDP/1, Bruno Zuppiger/1, Hinwil/1, Germain Mittaz/1, CVP/1, Pfister/1, Zuppiger/1, Hans Wiederkehr/1, Büchi/1
#
# Time: 5.48 sec
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Die Einzelinitiative lautet wie folgt: Es sei die Steuergesetzgebung des Kantons
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  so zu ändern, dass auf Erbanfällen und Schenkungen von Eltern an Kinder keine Erbschafts- bzw. Schenkungssteuer mehr erhoben wird. Die Begründung lautet wie folgt:<br><br>Zahlreiche Kantone besteuern Erbanfälle und Schenkungen von Eltern an Kinder nicht. Zu ihnen gehören die Kantone
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     
# Created a chunk of size 283, which is longer than the specified 256
# Created a chunk of size 274, which is longer than the specified 256
# Created a chunk of size 260, which is longer than the specified 256
# Created a chunk of size 293, which is longer than the specified 256
# Created a chunk of size 289, which is longer than the specified 256
# Created a chunk of size 289, which is longer than the specified 256
# Created a chunk of size 330, which is longer than the specified 256
# Created a chunk of size 278, which is longer than the specified 256
# Created a chunk of size 279, which is longer than the specified 256
# Created a chunk of size 331, which is longer than the specified 256
# Created a chunk of size 280, which is longer than the specified 256
# Created a chunk of size 283, which is longer than the specified 256
# Created a chunk of size 281, which is longer than the specified 256
# Created a chunk of size 259, which is longer than the specified 256
# Created a chunk of size 279, which is longer than the specified 256
# Created a chunk of size 296, which is longer than the specified 256
# Created a chunk of size 271, which is longer than the specified 256
# Created a chunk of size 349, which is longer than the specified 256
# Created a chunk of size 274, which is longer than the specified 256
# Created a chunk of size 260, which is longer than the specified 256
# Created a chunk of size 543, which is longer than the specified 256
# Created a chunk of size 262, which is longer than the specified 256
# Created a chunk of size 304, which is longer than the specified 256
# Created a chunk of size 322, which is longer than the specified 256
# Created a chunk of size 261, which is longer than the specified 256
# Created a chunk of size 300, which is longer than the specified 256
# Created a chunk of size 277, which is longer than the specified 256
# Created a chunk of size 333, which is longer than the specified 256
# Created a chunk of size 291, which is longer than the specified 256
# [('PER', 70), ('ORG', 43), ('LOC', 130)]
# Pöschwies/35, Zürich/34, Regensdorf/16, Kloten/12, Schweiz/10, FDP/7, SP/6, Holm/5, Spieler/5, ANAG/4, Grüne/4, Willy Spieler/4, SVP/4, Rudolf Jeker/3, Mario Fehr/3, Dielsdorf/3, Grünen/3, Bülach/3, EVP/3, EJPD/2, Küsnacht/2, Adliswil/2, Rietiker/2, Frutig/2, Daniel Vischer/2, Gut/2, Aisslinger/2, Leuenberger/2, Homberger/2, Waid/2, Weil/2, FraP!/2, Mossdorf/2, Vischer/2, Peter Grau/2, SD/2, Neukomm/2, Robert Neukomm/2, Styger/2, Genf/1, Esther Holm/1, Horgen/1, Bundesrat/1, Rote Kreuz/1, Germain Mittaz/1, CVP/1, Dietikon/1, Dorothée Fierz/1, Egg/1, Kaspar Günthardt/1, Dällikon/1, Südafrika/1, Robert Rietiker/1, Maur/1, Susanne Frutig/1, Peter Aisslinger/1, Günthardt/1, Fierz/1, Arche Noah/1, Noah/1, Bern/1, Werner Scherrer/1, Uster/1, Anjuska/1, Zürichs/1, Jugoslawien/1, Sri Lanka/1, Algerien/1, Europa/1, Martin Mossdorf/1, Laurenz Styger/1, Erhard Bernet/1, FPS/1, Freiburg/1, Moritz Leuenberger/1, Fehr/1, Ernst Homberger/1, Bund/1
#
# Time: 20.90 sec
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Dr.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rudolf Jeker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FDP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ), Präsident der vorberatenden Kommission: Wir behandeln den Antrag des Regierungsrates 3421, Beschluss des Kantonsrates betreffend die Bewilligung eines Kredits für die Erweiterung der Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , um eine geschlossene Abteilung mit 60 Plätzen;<br><br>hier wird ein Kredit von 16,1 Millionen Franken zur Bewilligung beantragt. Der zweite Antrag, 3428, betrifft den Antrag für die Bewilligung eines Kredits von 19,7 Millionen Franken für den Bau eines zweiten Ausschaffungsgefängnisses in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kloten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .<br><br>Die allgemeine Situation im zürcherischen Gefängniswesen darf mindestens wie sie in der Presse dargestellt und in der Bevölkerung auch wahrgenommen wird als bekannt vorausgesetzt werden.<br><br>Ich werde mich deshalb kurz fassen und in einem ersten Teil meiner Ausführungen die Lagebeurteilung des Regierungsrates gemäss den Weisungen gerafft wiedergeben, um dann in einem zweiten Teil auf die Kommissionsberatungen einzugehen.<br><br>Vorlage 3421 (Erweiterung der Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# )<br><br>Das Konzept für die neue Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , die im Frühling 1995 bezogen wurde, beruht in seinen Grundzügen auf den Feststellungen der in den Jahren 1972 bis 1976 tätigen Planungskommission.<br><br>Während sowohl in betrieblicher Hinsicht, wie bei der Ausrüstung, insbesondere die Sicherheitsvorkehren, im Rahmen der weiteren Bearbeitung des aus dem Jahr 1980 stammenden Wettbewerbsprojekts stammten, ist die Bauausführung verschiedentlich der Situation angepasst worden.<br><br>Die Kapazität umfasst heute rund 350 Plätze. Wie es sich gezeigt hat, ist diese Anzahl der zur Verfügung stehenden Plätze zu knapp.<br><br>Insbesondere der Anstieg des Bestandes an ausländischen Strafgefangenen, die wegen Fluchtgefahr in geschlossenen Anstalten unterzubringen sind, aber auch die Zunahme von längeren Strafen haben dazu geführt, dass in letzter Zeit immer zwischen 50 und 100 Verurteilte in Bezirksgefängnissen auf die Verlegung in die vollbelegte Strafanstalt warten müssen.<br><br>Das trägt massgeblich zur Überbelegung der Bezirksgefängnisse bei. Verschiedene betriebliche und sicherheitstechnische Überlegungen haben zur Ausarbeitung eines Projekts für die Schaffung einer zusätzlichen Abteilung mit zweimal 30 Plätzen Anlass gegeben.<br><br>Der Sicherheitsstandard wurde so festgelegt, dass er demjenigen der geschlossenen Abteilungen entspricht, und die wegen der begrenzten Kapazität der Werkstätten ohnehin erforderliche Unterbringung von Arbeitsräumen in der Abteilung selbst erlaubt die gleiche Art des Betriebs wie in jenen Abteilungen, die bereits heute im Gefängnis bestehen.<br><br>Das Projekt der Erweiterung zeigt sich in der Situation so, dass ein eigenständiger Bau innerhalb der Umfassungsmauer gelegt werden soll und damit das Raumprogramm für 60 zusätzliche Plätze realisiert werden kann.<br><br>Die Kosten des Projekts belaufen sich auf total 16,1 Millionen Franken. Es darf, wie bei diesen Gefängnisbauten üblich, ein Anteil des Bundes in der Grössenordnung von 40% bis 50% erwartet werden.<br><br>Der Regierungsrat kommt in seinen Weisungen zum folgenden Schluss:<br><br>Mit der beantragten Erweiterung der Strafanstalt
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pöschwies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  um eine Abteilung mit 60 Plätzen wird deren Aufnahmekapazität um rund 20% erhöht, was zu einer erheblichen Entlastung der Bezirksgefängnisse führt, weil sich die Wartezeit für den Eintritt in die Strafanstalt verkürzt.<br><br>Gleichzeitig wird damit erreicht, dass die neue Strafanstalt über bessere Möglichkeiten für die Unterbringung des seit ihrer Planung angestiegenen Anteils an Gefangenen mit längeren Strafen und für die Aufteilung von Gefangenengruppen gleicher Nationalität oder ethischer Herkunft verfügt.<br><br>Vorlage 3428 (zweites Ausschaffungsgefängnis in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kloten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) Das neue Bundesrecht:<br><br>Mit dem in der Abstimmung vom Dezember angenommenen Bundesgesetz über Zwangsmassnahmen werden den rechtsanwendenden Behörden teils neue, teils bestehende, aber verschärfte Eingriffsmittel zur Verfügung gestellt.<br><br>Sie sollen sicherstellen, dass weggewiesene Ausländer auch tatsächlich ausreisen;<br><br>denn wie der Bundesrat zu den neuen Bestimmungen festgehalten hat der konsequente Wegweisungsvollzug von Ausländern, die in der
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schweiz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  keine Anwesenheitsbewilligung erhalten haben, stellt einen Grundpfeiler einer glaubwürdigen Asyl- und Auslän

# %% [markdown]
# # Export der Annotation als JSON zwecks Diff (separates Notebook)

# %%
datestr = datetime.now().replace(microsecond=0).isoformat()

with open("qualitative_evaluation_0_results_{}.json".format(datestr.replace(':','_')), "w") as f:
    f.write(json.dumps(result_json_dict, indent=4, ensure_ascii=False))

# %% [markdown]
# # Resultate
#
# ## Grobübersicht
#
# * **spaCy de_core_news_lg** erzeugt viele grob falsche False Positives (normale Nomen, Phrasen mit Adjektiven oder Adverben, ungewöhnliche oder falsch geschriebene Nichtnomen, auch mit kleinem Anfangsbuchstaben)
# * **SwissBert** weist gute Präzision auf Spans aus, die mit der Spacy-Tokenisierung (für spacy.blank("de")) zusammenfallen, erzeugt jedoch Artefakte auf Subtokenebene (trotz Aggregation der Subtoken im Output), inklusive Annotation von einzelnen Buchstaben und sogar leeren Strings. SwissBert bietet im Gegensatz zu SpanMarker keine direkte spaCy-Integration.
# * **Flair/ner-german-large**
#   * wirkt informell ähnlich präzise wie SwissBert, bietet jedoch den Vorteil einer Framework-Lösung (Textchunking, etc.)
#   * verursacht keine Span Errors; Tokenisierung weitgehend kompatibel mit spaCy
#   * Schnellste spaCy-Alternative
# * **SpanMarker** ist, je nach Modell, gleich schnell wie Swissbert bis dreimal langsamer, bei in etwa ähnlicher Leistung und schlechterer Skalierung mit längeren Dokumenten. Die Unterschiede zwischen den vier SpanMarker-Modellen sind geringfügig, wobei Gelectra am besten abschneidet. **SpanMarker kann direkt in spaCy eingebunden werden**: https://github.com/tomaarsen/SpanMarkerNER#using-pretrained-spanmarker-models-with-spacy
#
# ## Informeller Diff der Resultate - erster Eindruck
#
#  * SpanMarker Gelectra ist den anderen SpanMarker-Modellen überlegen, allerdings auch doppelt so rechenintensiv und damit ingesamt das mit Abstand teuerste Modell
#  * de_core_news_lg weist gegenüber Gelectra relativ wenige FN, dafür zahlreiche FP auf.
#  * SwissBERT hat hohe Präzision, jedoch geringe Ausbeute (viele FN bei PER)
#  * Flair schneidet leicht schlechter als SpanMarker Gelectra ab, bei deutlich besserer Laufzeit
#
# ## Laufzeiten (in Sekunden)
#
# Anmerkungen: Bei den Laufzeiten der HF-Modelle handelt es sich um Angaben ohne spaCy-Einbindung, die ungeachtet der Modellgrösse einen Overhead von 33-50% verursacht, mit der sich allerdings auch das Chunking erübrigt (Satztokenisierung).
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-uca5{text-align:left;text-decoration:underline;vertical-align:top}
# .tg .tg-dvid{background-color:#efefef;border-color:inherit;font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# .tg .tg-fymr{border-color:inherit;font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-b3sw{background-color:#efefef;font-weight:bold;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky"></th>
#     <th class="tg-dvid">Doc1</th>
#     <th class="tg-dvid">Doc2</th>
#     <th class="tg-dvid">Doc3</th>
# </thead>
# <tbody>
#     <tr>
#     <td class="tg-dvid"><i>Token</i></td>
#     <td class="tg-0pky"><i>2'079</i></td>
#     <td class="tg-0pky"><i>1'757</i></td>
#     <td class="tg-0pky"><i>10'508</i></td>
#   </tr>
#   <tr>
#     <td class="tg-dvid">de_core_news_md</td>
#     <td class="tg-0pky">0.07</td>
#     <td class="tg-0pky">0.05</td>
#     <td class="tg-0pky">0.29</td>
#   </tr>
#   <tr>
#     <td class="tg-dvid">de_core_news_lg</td>
#     <td class="tg-fymr">0.07</td>
#     <td class="tg-fymr">0.05</td>
#     <td class="tg-fymr">0.29</td>
#   </tr>
#   <tr><td/><td/><td/><td/></tr>
#   <tr>
#     <td class="tg-dvid">swissbert</td>
#     <td class="tg-0pky">2.37</td>
#     <td class="tg-0pky">1.53</td>
#     <td class="tg-0pky">9.14</td>
#   </tr>
#   <tr>
#     <td class="tg-dvid">sm_gelectra</td>
#     <td class="tg-0pky">7.18</td>
#     <td class="tg-0pky">5.22</td>
#     <td class="tg-0pky">30.36</td>
#   </tr>
#   <tr>
#     <td class="tg-dvid">sm_teams</td>
#     <td class="tg-0pky">4.13</td>
#     <td class="tg-0pky">2.69</td>
#     <td class="tg-0pky">15.60</td>
#   </tr>
#   <tr>
#     <td class="tg-dvid">sm_bert</td>
#     <td class="tg-0pky">2.96</td>
#     <td class="tg-0pky">2.40</td>
#     <td class="tg-0pky">14.49</td>
#   </tr>
#   <tr>
#     <td class="tg-dvid">sm_td_bert</td>
#     <td class="tg-0pky">2.90</td>
#     <td class="tg-0pky">2.46</td>
#     <td class="tg-0pky">14.61</td>
#   </tr>
#   <tr>
#     <td class="tg-dvid">fl_german_large<br>(w/ external chunking)</td>
#     <td class="tg-0pky">9.72</td>
#     <td class="tg-0pky">4.79</td>
#     <td class="tg-0pky">22.20</td>
#   </tr>
#   <tr>
#     <td class="tg-dvid">fl_german_large<br>(w/o external chunking)<br></td>
#     <td class="tg-0pky"><b>2.09</b></td>
#     <td class="tg-0pky"><b>0.67</b></td>
#       <td class="tg-0pky"><b>5.47</b></b></td>
#   </tr>
# </tbody>
# </table>
#
# # Entscheidungen hinsichtlich quantitativer Evaluation
#
# * Aus Gründen der Praktikabilität erfolgt eine Einschränkung auf folgende **drei Modelle** für die quantitative Erstevaluation.
#     1. SpanMarker Gelectra
#     2. FlairNLP
#     3. spaCy de_core_news_lg (als Baseline, Potenzial Fine-Tuning)
