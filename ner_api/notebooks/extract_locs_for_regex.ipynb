# %% [markdown]
# ## Regex zur Erkennung von Orten innerhalb von Organisationen aus amtlichem Ortschaftsverzeichnis und Kantonsliste erzeugen

# %%
import re
import pandas as pd

# Source: ortschaftenverzeichnis_plz_2056.csv.zip @ https://www.swisstopo.admin.ch/de/amtliches-ortschaftenverzeichnis#Ortschaftenverzeichnis--Download
# ©swisstopo

# Modify path depending on working directory of Jupyter environment
df = pd.read_csv("../resources/AMTOVZ_CSV_LV95.csv", sep=";")

# %% [markdown]
# Kantonsnamen

# %%
cantons = {
    "Aargau",
    "Appenzell Innerrhoden",
    "Innerrhoden",
    "Appenzell Ausserrhoden",
    "Ausserrhoden",
    "Bern",
    "Basel-Landschaft",
    "Basel-Land",
    "Basel Land",
    "Baselland",
    "Baselbiet",
    "Basel-Stadt",
    "Basel Stadt",
    "Baselstadt",
    "Fribourg",
    "Freiburg",
    "Genève",
    "Genf",
    "Glarus",
    "Graubünden",
    "Grischun",
    "Jura",
    "Luzern",
    "Neuchâtel",
    "Neuenburg",
    "Nidwalden",
    "Obwalden",
    "St. Gallen",
    "Sankt Gallen",
    "Schaffhausen",
    "Solothurn",
    "Schwyz",
    "Thurgau",
    "Ticino",
    "Tessin",
    "Uri",
    "Vaud",
    "Waadt",
    "Valais",
    "Wallis",
    "Zug",
    "Zürich",
}

# %%
df
# Out:
#           Ortschaftsname   PLZ  Zusatzziffer        Gemeindename  BFS-Nr  \
# 0        Aeugst am Albis  8914             0     Aeugst am Albis       1
# 1            Aeugstertal  8914             2     Aeugst am Albis       1
# 2              Zwillikon  8909             0  Affoltern am Albis       2
# 3     Affoltern am Albis  8910             0  Affoltern am Albis       2
# 4             Bonstetten  8906             0          Bonstetten       3
# ...                  ...   ...           ...                 ...     ...
# 5729           Mauren FL  9493             0              Mauren    7008
# 5730             Nendeln  9485             0             Gamprin    7009
# 5731     Gamprin-Bendern  9487             0             Gamprin    7009
# 5732             Ruggell  9491             0             Ruggell    7010
# 5733        Schellenberg  9488             0        Schellenberg    7011
#
#      Kantonskürzel            E            N Sprache    Validity
# 0               ZH  2679402.872  1235842.010      de  2008-07-01
# 1               ZH  2679815.372  1237404.310      de  2008-07-01
# 2               ZH  2675280.133  1238108.286      de  2008-07-01
# 3               ZH  2676852.012  1236929.718      de  2008-07-01
# 4               ZH  2677412.150  1241078.278      de  2008-07-01
# ...            ...          ...          ...     ...         ...
# 5729           NaN  2759637.820  1231945.121      de  2008-07-01
# 5730           NaN  2759978.270  1229651.126      de  2008-07-01
# 5731           NaN  2757125.670  1232514.364      de  2008-07-01
# 5732           NaN  2758648.719  1235172.319      de  2008-07-01
# 5733           NaN  2759708.282  1233349.815      de  2008-07-01
#
# [5734 rows x 10 columns]

# %% [markdown]
# Analyse der kürzesten Ortschaft- und Gemeindesnamen in Hinblick auf allfällige False Positives.

# %%
sorted(list(set(df["Ortschaftsname"])), key=lambda x: len(x))
# Out:
# ['Lü',
#  'Gy',
#  'Vex',
#  'Vnà',
#  'Loc',
#  'Fey',
#  'Auw',
#  'Sur',
#  'Oey',
#  'Sax',
#  'Lax',
#  'Asp',
#  'Zug',
#  'Fex',
#  'Rue',
#  'Nax',
#  'Naz',
#  'Ins',
#  'Bex',
#  'Elm',
#  'Juf',
#  'Mon',
#  'Binz',
#  'Yens',
#  'Chur',
#  'Nivo',
#  'Mels',
#  'Erde',
#  'Agno',
#  'Vrin',
#  'Brig',
#  'Gudo',
#  'Caux',
#  'Baar',
#  'Onex',
#  'Ursy',
#  'Tann',
#  'Orny',
#  'Bôle',
#  'Dizy',
#  'Horw',
#  'Glis',
#  'Lyss',
#  'Aran',
#  'Aven',
#  'Rain',
#  'Nyon',
#  'Maur',
#  'Pfyn',
#  'Boll',
#  'Embd',
#  'Mund',
#  'Sent',
#  'Birr',
#  'Sarn',
#  'Riex',
#  'Iseo',
#  'Gals',
#  'Eriz',
#  'Worb',
#  'Mols',
#  'Trey',
#  'Engi',
#  'Dino',
#  'Port',
#  'Riom',
#  'Croy',
#  'Says',
#  'Wila',
#  'Etoy',
#  'Cimo',
#  'Ftan',
#  'Aïre',
#  'Pura',
#  'Ayer',
#  'Jens',
#  'Vals',
#  'Agra',
#  'Watt',
#  'Zuoz',
#  'Lüen',
#  'Noës',
#  'Giez',
#  'Visp',
#  'Nohl',
#  'Gohl',
#  'Vich',
#  'Bure',
#  'Präz',
#  'Alle',
#  'Buus',
#  'Arzo',
#  'Igis',
#  'Pomy',
#  'Seon',
#  'Miex',
#  'Pizy',
#  'Trun',
#  'Loco',
#  'Riaz',
#  'Suhr',
#  'Font',
#  'Gais',
#  'Elgg',
#  'Sutz',
#  'Murg',
#  'Mies',
#  'Thal',
#  'Eich',
#  'Thun',
#  'Pany',
#  'Höri',
#  'Arch',
#  'Matt',
#  'Bern',
#  'Fiez',
#  'Mase',
#  'Arth',
#  'Sion',
#  'Binn',
#  'Jona',
#  'Carì',
#  'Lens',
#  'Belp',
#  'Osco',
#  'Orbe',
#  'Trub',
#  'Cama',
#  'Broc',
#  'Péry',
#  'Sool',
#  'Dorf',
#  'Rafz',
#  'Rona',
#  'Fahy',
#  'Cham',
#  'Gams',
#  'Buix',
#  'Putz',
#  'Flüh',
#  'Horn',
#  'Root',
#  'Rufi',
#  'Siat',
#  'Nods',
#  'Trin',
#  'Rasa',
#  'Jaun',
#  'Sins',
#  'Gasel',
#  'Cully',
#  'Erlen',
#  'Furna',
#  'Ebnet',
#  'Jonen',
#  'Laura',
#  'Forch',
#  'Brail',
#  'Féchy',
#  'Lätti',
#  'Syens',
#  'Gland',
#  'Flond',
#  'Nidau',
#  'Grône',
#  'Wängi',
#  'Soral',
#  'Curio',
#  'Realp',
#  'Lossy',
#  'Thyon',
#  'Axalp',
#  'Weite',
#  'Brent',
#  'Bivio',
#  'Vaduz',
#  'Susch',
#  'Arosa',
#  'Fully',
#  'Wäldi',
#  'Sévaz',
#  'Elsau',
#  'Vessy',
#  'Grabs',
#  'Vesin',
#  'Bonau',
#  'Jussy',
#  'Orvin',
#  'Isone',
#  'Ladir',
#  'Oggio',
#  'Grono',
#  'Uster',
#  'Wagen',
#  'Bowil',
#  'Banco',
#  'Täsch',
#  'Bogno',
#  'Uzwil',
#  'Borex',
#  'Donat',
#  'Grens',
#  'Colla',
#  'Bauen',
#  'Ulmiz',
#  'Lavin',
#  'Scuol',
#  'Vezio',
#  'Kerns',
#  'Rueun',
#  'Posat',
#  'Ueken',
#  'Rolle',
#  'Rütli',
#  'Malix',
#  'Henau',
#  'Köniz',
#  'Warth',
#  'Bözen',
#  'Gross',
#  'Frick',
#  'Wangs',
#  'Meien',
#  'Aarau',
#  'Ranzo',
#  'Vella',
#  'Basel',
#  'Wikon',
#  'Muhen',
#  'Ambrì',
#  'Agarn',
#  'Emmen',
#  'Pagig',
#  'Lienz',
#  'Bière',
#  'Peist',
#  'Saxon',
#  'Olten',
#  'Sagno',
#  'Gilly',
#  'Spiez',
#  'Fidaz',
#  'Miège',
#  'Flums',
#  'Büron',
#  'Wavre',
#  'Bauma',
#  'Riveo',
#  'Dalin',
#  'Widen',
#  'Enges',
#  'Fusio',
#  'Filet',
#  'Ibach',
#  'Bever',
#  'Stäfa',
#  'Inwil',
#  'Suchy',
#  'Turgi',
#  'Arbon',
#  'Sfazù',
#  'Vevey',
#  'Ardez',
#  'Seiry',
#  'Someo',
#  'Missy',
#  'Jenaz',
#  'Bulle',
#  'Degen',
#  'Risch',
#  'Lanna',
#  'Eiken',
#  'Inden',
#  'Stans',
#  'Orges',
#  'Bondo',
#  'Dalpe',
#  'Stels',
#  'Choëx',
#  'Mosen',
#  'Dully',
#  'Jeuss',
#  'Viano',
#  'Faoug',
#  'Au ZH',
#  'Vasön',
#  'Tegna',
#  'Claro',
#  'Gryon',
#  'Ogens',
#  'Cozzo',
#  'Rovio',
#  'Mumpf',
#  'Réchy',
#  'Lonay',
#  'Ilanz',
#  'Crana',
#  'Luven',
#  'Court',
#  'Trans',
#  'Lutry',
#  'Bachs',
#  'Tobel',
#  'Marly',
#  'Fenin',
#  'Randa',
#  'Aigle',
#  'Ernen',
#  'Honau',
#  'Russo',
#  'Vezia',
#  'Zuben',
#  'Raron',
#  'Amden',
#  'Au TG',
#  'Ardon',
#  'Avers',
#  'Danis',
#  'Asuel',
#  'Rossa',
#  'Luins',
#  'Salez',
#  'Cauco',
#  'Baden',
#  'Alten',
#  'Gondo',
#  'Glion',
#  'Breno',
#  'Panex',
#  'Manno',
#  'Mörel',
#  'Au SG',
#  'Tenna',
#  'Cevio',
#  'Plons',
#  'Faido',
#  'Fanas',
#  'Enney',
#  'Sessa',
#  'Signy',
#  'Anwil',
#  'Preda',
#  'Riein',
#  'Monte',
#  'Perly',
#  'Augio',
#  'Cazis',
#  'Torre',
#  'Gimel',
#  'Selma',
#  'Porza',
#  'Cadro',
#  'Pully',
#  'Geiss',
#  'Bärau',
#  'Russy',
#  'Zinal',
#  'Arbaz',
#  'Greng',
#  'Rengg',
#  'Rivaz',
#  'Duvin',
#  'Wynau',
#  'Varen',
#  'Niouc',
#  'Agiez',
#  'Twann',
#  'Lalden',
#  'Orzens',
#  'Torgon',
#  'St-Luc',
#  'Brusio',
#  'Sierre',
#  'Moleno',
#  'Aumont',
#  'Bitsch',
#  'Liddes',
#  'Jenins',
#  'Cremin',
#  'Ferden',
#  'Strada',
#  'Buseno',
#  'Collex',
#  'Uvrier',
#  'Cabbio',
#  'Dozwil',
#  'Soazza',
#  'Noréaz',
#  'Wimmis',
#  'Wabern',
#  'Lausen',
#  'Bühler',
#  'Cronay',
#  'Prêles',
#  'Stabio',
#  'Cheiry',
#  'Schaan',
#  'Leysin',
#  'Astano',
#  'Trient',
#  'Cuarny',
#  'Spruga',
#  'Egnach',
#  'Nassen',
#  'Andeer',
#  'Casima',
#  'Rueras',
#  'Wil AG',
#  'Eysins',
#  'Pigniu',
#  'Boswil',
#  'Buhwil',
#  'Laufen',
#  'Seehof',
#  'Hallau',
#  'Sedrun',
#  'Sassel',
#  'Genève',
#  'Arolla',
#  'Founex',
#  'Vaglio',
#  'Ruswil',
#  'Misery',
#  'Assens',
#  'Bevaix',
#  'Erlach',
#  'Trélex',
#  'Graben',
#  'Gunten',
#  'Ziefen',
#  'Hinwil',
#  'Veyras',
#  'Guarda',
#  'Peseux',
#  'Gadmen',
#  'Fiesch',
#  'Crésuz',
#  'Frasco',
#  'Gresso',
#  'Maggia',
#  'Mex VD',
#  'Wengen',
#  'Halten',
#  'Stilli',
#  'Carena',
#  'Clugin',
#  'Dicken',
#  'Plagne',
#  'Näfels',
#  'Scheid',
#  'Morges',
#  'Rennaz',
#  'Castro',
#  'Goldau',
#  'Tenero',
#  'Platta',
#  'Etzgen',
#  'Uznach',
#  'Aquila',
#  'Künten',
#  'Icogne',
#  'Urmein',
#  'Vétroz',
#  'Gruben',
#  'Russin',
#  'Wil ZH',
#  'Huémoz',
#  'Widnau',
#  'Arvigo',
#  'Sergey',
#  'Worben',
#  'Mutrux',
#  'Grünen',
#  'Kriens',
#  'Murten',
#  'Lessoc',
#  'Lumino',
#  'Berken',
#  'Rivera',
#  'Meggen',
#  'Alosen',
#  'Saland',
#  'Peiden',
#  'Wiggen',
#  'Tamins',
#  'Reiden',
#  'Mossel',
#  'Biglen',
#  'Euthal',
#  'Camedo',
#  'Molare',
#  'Seewil',
#  'Gempen',
#  'Vinzel',
#  'Lunden',
#  'Buttes',
#  'Altwis',
#  'Sulgen',
#  'Bedano',
#  'Tartar',
#  'Gressy',
#  'Tannay',
#  'Trogen',
#  'Vattiz',
#  'Salins',
#  'Osogna',
#  'Chamby',
#  'Riddes',
#  'Lovens',
#  'Bennau',
#  'Winden',
#  'Dongio',
#  'Pailly',
#  'Weggis',
#  'Muggio',
#  'Sagogn',
#  'Thusis',
#  'Bolken',
#  'Pignia',
#  'Ligerz',
#  'Buochs',
#  'Mutten',
#  'Romoos',
#  'Masein',
#  'Bonfol',
#  'Cunter',
#  'Iragna',
#  'Flaach',
#  'Vouvry',
#  'Bernex',
#  'Versam',
#  'Azmoos',
#  'Bilten',
#  'Gammen',
#  "L'Isle",
#  'Meilen',
#  'Contra',
#  'Camuns',
#  'Bullet',
#  'Morlon',
#  'Altnau',
#  'Eisten',
#  'Messen',
#  'Delley',
#  'Giswil',
#  'Tafers',
#  'Zuzgen',
#  'Rabius',
#  'Tatroz',
#  'Lamone',
#  'Fläsch',
#  'Luzern',
#  'Stampa',
#  'Soglio',
#  'Kippel',
#  'Avully',
#  'Horgen',
#  'Comano',
#  'Moneto',
#  'Chancy',
#  'Greich',
#  'Vinelz',
#  'Oppens',
#  'Nuglar',
#  'Blonay',
#  'Rovray',
#  'Egg SZ',
#  'Lauwil',
#  'Golino',
#  'Biasca',
#  'Monnaz',
#  'Arogno',
#  'Diesse',
#  'Kiesen',
#  'Weiach',
#  'Coeuve',
#  'Matran',
#  'Porsel',
#  'Vättis',
#  'Tuggen',
#  'Praden',
#  'Denens',
#  'Luzein',
#  'Saulcy',
#  'Corban',
#  'Soulce',
#  'Agasul',
#  'Iffwil',
#  'Toffen',
#  'Uezwil',
#  'Milken',
#  'Halden',
#  'Winkel',
#  'Bülach',
#  'Maules',
#  'Mathod',
#  'Pringy',
#  'Möhlin',
#  'Grancy',
#  'Hurden',
#  'Knonau',
#  'Chigny',
#  'Flawil',
#  'Uttwil',
#  'Almens',
#  'Amsteg',
#  'Heiden',
#  'Zizers',
#  'Insone',
#  'Rances',
#  'Krinau',
#  'Sattel',
#  'Murist',
#  'Saanen',
#  'Ocourt',
#  'Arnegg',
#  'Ramsen',
#  'Dardin',
#  'Bruson',
#  'Ramsei',
#  'Zürich',
#  'Brünig',
#  'Illgau',
#  'Glarus',
#  'Gnosca',
#  'Odogno',
#  'Ebikon',
#  'Mathon',
#  'Urswil',
#  'Losone',
#  'Aranno',
#  'Wauwil',
#  'Cumbel',
#  'Zernez',
#  'Sévery',
#  'Airolo',
#  'Falera',
#  'Fehren',
#  'Orpund',
#  'Illnau',
#  'Chemin',
#  'Buonas',
#  'Apples',
#  'Linden',
#  'Aadorf',
#  'Hirzel',
#  'Küblis',
#  'Wil SG',
#  'Sobrio',
#  'Törbel',
#  'Denezy',
#  'Sorens',
#  'Hüswil',
#  'Gstaad',
#  'Salvan',
#  'Gamsen',
#  'Mühlau',
#  'Magden',
#  'Auswil',
#  'Levron',
#  'Leggia',
#  'Vallon',
#  'Ropraz',
#  'Blauen',
#  'Peccia',
#  'Le Bry',
#  'Zignau',
#  'Riehen',
#  'Mülchi',
#  'Rorbas',
#  'Moudon',
#  'Inkwil',
#  'Areuse',
#  'Coglio',
#  'Kyburg',
#  'Avegno',
#  'Jaberg',
#  'Zeihen',
#  'Alikon',
#  'Coppet',
#  'Lugano',
#  'Surava',
#  'Scherz',
#  'Souboz',
#  'Ipsach',
#  'Lupfig',
#  'Anzère',
#  'Figino',
#  'Valens',
#  'Lindau',
#  'Jongny',
#  'Sursee',
#  'Latsch',
#  'Perroy',
#  'Sarnen',
#  'Hütten',
#  'Lodano',
#  'Prilly',
#  'Eschen',
#  'Perlen',
#  'Urdorf',
#  'Arbedo',
#  'Gähwil',
#  'Dangio',
#  'Melide',
#  'Maloja',
#  'Schwyz',
#  'Betten',
#  'Eyholz',
#  'Sufers',
#  'Gonten',
#  'Bouloz',
#  'Bister',
#  'Boudry',
#  'Lugnez',
#  'Schötz',
#  'Sugiez',
#  'Parpan',
#  'Mauraz',
#  'Naters',
#  'Cornol',
#  'Ursins',
#  'Lauerz',
#  'Umiken',
#  'Mürren',
#  'Signau',
#  'Segnas',
#  'Grüsch',
#  'Mettau',
#  'Vadura',
#  'Meride',
#  'Saules',
#  'Tarasp',
#  'Quinto',
#  'Middes',
#  'Paudex',
#  'Bavois',
#  'Belalp',
#  'Mex VS',
#  'Galmiz',
#  'Allens',
#  'Mollis',
#  'Termen',
#  'Dreien',
#  'Muolen',
#  'Gurbrü',
#  'Lucens',
#  'Weesen',
#  'Zillis',
#  'Daiwil',
#  'Suberg',
#  'Märwil',
#  'Piotta',
#  'Epsach',
#  'Kloten',
#  'Vermes',
#  'Salouf',
#  'Gampel',
#  'Aclens',
#  'Melano',
#  'Arosio',
#  'Bünzen',
#  'Necker',
#  'Soubey',
#  'Epagny',
#  'Carona',
#  'Meyrin',
#  'Denges',
#  'Rodels',
#  'Tübach',
#  'Couvet',
#  'Gersau',
#  'Savosa',
#  'Susten',
#  'Yvorne',
#  'Mugena',
#  'Volken',
#  'Ascona',
#  'Lommis',
#  'Neggio',
#  'Thônex',
#  'Dietwil',
#  'Cheyres',
#  'Zezikon',
#  'Anières',
#  'Zäziwil',
#  'Gordola',
#  'Baulmes',
#  'Vairano',
#  'Sempach',
#  'Seuzach',
#  'Schänis',
#  'Albeuve',
#  'Netstal',
#  'Bassins',
#  'Aubonne',
#  'Fuldera',
#  'Zullwil',
#  'Sommeri',
#  'Mülenen',
#  'Le Fuet',
#  'Dachsen',
#  'Juriens',
#  'Lungern',
#  'Gunzgen',
#  'Mammern',
#  'Wittnau',
#  'Rheinau',
#  'Moutier',
#  'Céligny',
#  'Parsonz',
#  'Itingen',
#  'Curtina',
#  'Zénauva',
#  'Chénens',
#  'Lyssach',
#  'Olivone',
#  'Lavigny',
#  'Campora',
#  'Sünikon',
#  'Goldach',
#  'Balgach',
#  'Autigny',
#  'Travers',
#  'Berolle',
#  'Berg TG',
#  'Müstair',
#  'Nuvilly',
#  'Aminona',
#  'Evolène',
#  'Nesslau',
#  'Quarten',
#  'Zetzwil',
#  'Wolfwil',
#  'Savièse',
#  'Passugg',
#  'Boulens',
#  'Andiast',
#  'Gingins',
#  'Rancate',
#  'Hoffeld',
#  'Aarberg',
#  'Bidogno',
#  'Bürchen',
#  'Süderen',
#  'Ohmstal',
#  'Dinhard',
#  'Cologny',
#  'Pohlern',
#  'Chippis',
#  'Dornach',
#  'Vernate',
#  'Esmonts',
#  'Winznau',
#  'La Tine',
#  'Goumois',
#  'Gorduno',
#  'Origlio',
#  'Lohn GR',
#  'Zuchwil',
#  'Muri AG',
#  'Progens',
#  'Saubraz',
#  'Le Lieu',
#  'Prahins',
#  'Leutwil',
#  'Wald AR',
#  'Tecknau',
#  'Satigny',
#  'Kottwil',
#  'Concise',
#  'Sirnach',
#  'Veytaux',
#  'Gandria',
#  'Grächen',
#  'Menznau',
#  'Braunau',
#  'Urnäsch',
#  'Fétigny',
#  'Silenen',
#  'Embrach',
#  'Baldegg',
#  'Gisikon',
#  'Berzona',
#  'Ufhusen',
#  'Tägerig',
#  'Martina',
#  'Böbikon',
#  'Morcles',
#  'Sissach',
#  'Bannwil',
#  'Leytron',
#  'Tremona',
#  'Vuadens',
#  'Hottwil',
#  'Paspels',
#  'Bratsch',
#  'Oleyres',
#  'Maracon',
#  'Surrein',
#  'Allaman',
#  'Attikon',
#  'Gossens',
#  'Riedern',
#  'Fideris',
#  'Morcote',
#  'Sarzens',
#  'Epesses',
#  'Vaulion',
#  'Treiten',
#  'Berlens',
#  'Eschenz',
#  'Illhart',
#  'Seleute',
#  'Puidoux',
#  'Triesen',
#  'Ebersol',
#  'Bramois',
#  'Tennwil',
#  'Vulpera',
#  'Zumikon',
#  'Wattwil',
#  'Sevgein',
#  'Lohn SH',
#  'Arveyes',
#  'Engwang',
#  'Pugerna',
#  'Rümlang',
#  'Kerzers',
#  'Caviano',
#  'Flüelen',
#  'Bercher',
#  'Chernex',
#  'Pfäfers',
#  'Sonogno',
#  'Oberems',
#  'Molinis',
#  'Luthern',
#  'Pensier',
#  'Wilihof',
#  'Thürnen',
#  'Grolley',
#  'Mandach',
#  'Posieux',
#  'Greppen',
#  'Seeberg',
#  'Winikon',
#  'Ballens',
#  'Contone',
#  'Mattwil',
#  'Rossura',
#  'Schiers',
#  'Hagneck',
#  'Sisikon',
#  'Arcegno',
#  'Schlans',
#  'Gurmels',
#  'Ramosch',
#  'Senèdes',
#  'Ersigen',
#  'Turbach',
#  'Cotterd',
#  'Nidfurn',
#  'Berneck',
#  'Alpthal',
#  'Brunnen',
#  'Mitlödi',
#  'Rombach',
#  'Hundwil',
#  'La Praz',
#  'Buch SH',
#  'Tschlin',
#  'Eriswil',
#  'Nendeln',
#  'Yvonand',
#  'Vionnaz',
#  'Vicques',
#  'Chanéaz',
#  'Meinier',
#  'Rocourt',
#  'Ravoire',
#  'Troinex',
#  'Safnern',
#  'Root D4',
#  'Fontnas',
#  'Charrat',
#  'Cugy VD',
#  'Marolta',
#  'Pfungen',
#  'Mettlen',
#  'S-chanf',
#  'Homburg',
#  'Mörigen',
#  'Riniken',
#  'Bioggio',
#  'Brenles',
#  'Vogorno',
#  'Samedan',
#  'Utzigen',
#  'Sumvitg',
#  ...]

# %%
sorted(list(set(df["Gemeindename"])), key=lambda x: len(x))
# Out:
# ['Gy',
#  'Egg',
#  'Vex',
#  'Fey',
#  'Auw',
#  'Lax',
#  'Zug',
#  'Rue',
#  'Ins',
#  'Bex',
#  'Yens',
#  'Chur',
#  'Mels',
#  'Agno',
#  'Prez',
#  'Baar',
#  'Onex',
#  'Ursy',
#  'Orny',
#  'Dizy',
#  'Horw',
#  'Lyss',
#  'Rain',
#  'Bühl',
#  'Nyon',
#  'Maur',
#  'Pfyn',
#  'Embd',
#  'Birr',
#  'Gals',
#  'Eriz',
#  'Worb',
#  'Trey',
#  'Port',
#  'Croy',
#  'Avry',
#  'Wila',
#  'Etoy',
#  'Pura',
#  'Oron',
#  'Jens',
#  'Vals',
#  'Zuoz',
#  'Giez',
#  'Visp',
#  'Lenk',
#  'Vich',
#  'Bure',
#  'Alle',
#  'Buus',
#  'Pomy',
#  'Seon',
#  'Leuk',
#  'Trun',
#  'Riaz',
#  'Suhr',
#  'Gais',
#  'Elgg',
#  'Mies',
#  'Thal',
#  'Eich',
#  'Thun',
#  'Höri',
#  'Arch',
#  'Bern',
#  'Fiez',
#  'Arth',
#  'Sion',
#  'Binn',
#  'Laax',
#  'Lens',
#  'Belp',
#  'Orbe',
#  'Trub',
#  'Cama',
#  'Broc',
#  'Goms',
#  'Dorf',
#  'Rafz',
#  'Fahy',
#  'Cham',
#  'Gams',
#  'Horn',
#  'Root',
#  'Nods',
#  'Trin',
#  'Jaun',
#  'Sins',
#  'Erlen',
#  'Furna',
#  'Jonen',
#  'Féchy',
#  'Syens',
#  'Gland',
#  'Nidau',
#  'Grône',
#  'Wängi',
#  'Soral',
#  'Curio',
#  'Augst',
#  'Realp',
#  'Flims',
#  'Vaduz',
#  'Arosa',
#  'Fully',
#  'Wäldi',
#  'Sévaz',
#  'Elsau',
#  'Grabs',
#  'Jussy',
#  'Orvin',
#  'Isone',
#  'Grono',
#  'Uster',
#  'Bowil',
#  'Täsch',
#  'Uzwil',
#  'Borex',
#  'Sauge',
#  'Grens',
#  'Ulmiz',
#  'Scuol',
#  'Kerns',
#  'Rolle',
#  'Köniz',
#  'Frick',
#  'Aarau',
#  'Basel',
#  'Wikon',
#  'Muhen',
#  'Agarn',
#  'Emmen',
#  'Bière',
#  'Saxon',
#  'Olten',
#  'Avusy',
#  'Gilly',
#  'Spiez',
#  'Flums',
#  'Büron',
#  'Bauma',
#  'Widen',
#  'Enges',
#  'Bever',
#  'Stäfa',
#  'Inwil',
#  'Suchy',
#  'Arbon',
#  'Vevey',
#  'Brugg',
#  'Missy',
#  'Jenaz',
#  'Bulle',
#  'Risch',
#  'Eiken',
#  'Inden',
#  'Stans',
#  'Orges',
#  'Dalpe',
#  'Sâles',
#  'Dully',
#  'Faoug',
#  'Ollon',
#  'Brügg',
#  'Gryon',
#  'Ogens',
#  'Mumpf',
#  'Lonay',
#  'Davos',
#  'Court',
#  'Lutry',
#  'Bachs',
#  'Marly',
#  'Randa',
#  'Aigle',
#  'Ernen',
#  'Honau',
#  'Vezia',
#  'Moiry',
#  'Raron',
#  'Amden',
#  'Ardon',
#  'Avers',
#  'Rossa',
#  'Luins',
#  'Tresa',
#  'Baden',
#  'Manno',
#  'Cevio',
#  'Faido',
#  'Torny',
#  'Anwil',
#  'Bodio',
#  'Lancy',
#  'Cazis',
#  'Gimel',
#  'Wengi',
#  'Porza',
#  'Pully',
#  'Arbaz',
#  'Greng',
#  'Ayent',
#  'Rivaz',
#  'Wynau',
#  'Varen',
#  'Agiez',
#  'Lalden',
#  'Orzens',
#  'Brusio',
#  'Sierre',
#  'Bitsch',
#  'Liddes',
#  'Jenins',
#  'Ferden',
#  'Buseno',
#  'Dozwil',
#  'Soazza',
#  'Wimmis',
#  'Lausen',
#  'Bühler',
#  'Cronay',
#  'Stabio',
#  'Schaan',
#  'Leysin',
#  'Astano',
#  'Trient',
#  'Cuarny',
#  'Egnach',
#  'Andeer',
#  'Wartau',
#  'Seewen',
#  'Eysins',
#  'Boswil',
#  'Laufen',
#  'Seehof',
#  'Hallau',
#  'Genève',
#  'Founex',
#  'Ruswil',
#  'Erlach',
#  'Trélex',
#  'Graben',
#  'Ziefen',
#  'Hinwil',
#  'Valsot',
#  'Fiesch',
#  'Crésuz',
#  'Maggia',
#  'Halten',
#  'Morges',
#  'Rennaz',
#  'Uznach',
#  'Künten',
#  'Icogne',
#  'Urmein',
#  'Vétroz',
#  'Russin',
#  'Widnau',
#  'Sergey',
#  'Worben',
#  'Mutrux',
#  'Kriens',
#  'Murten',
#  'Lumino',
#  'Berken',
#  'Meggen',
#  'Böztal',
#  'Tamins',
#  'Reiden',
#  'Biglen',
#  'Wahlen',
#  'Vinzel',
#  'Gempen',
#  'Sulgen',
#  'Bedano',
#  'Tannay',
#  'Trogen',
#  'Riddes',
#  'Pailly',
#  'Weggis',
#  'Sagogn',
#  'Thusis',
#  'Bolken',
#  'Ligerz',
#  'Buochs',
#  'Romoos',
#  'Masein',
#  'Flaach',
#  'Vouvry',
#  'Bernex',
#  "L'Isle",
#  'Meilen',
#  'Bullet',
#  'Morlon',
#  'Altnau',
#  'Eisten',
#  'Messen',
#  'Giswil',
#  'Tafers',
#  'Zuzgen',
#  'Lamone',
#  'Fläsch',
#  'Luzern',
#  'Kippel',
#  'Avully',
#  'Horgen',
#  'Comano',
#  'Flühli',
#  'Chancy',
#  'Surses',
#  'Lachen',
#  'Vinelz',
#  'Oppens',
#  'Rovray',
#  'Mauren',
#  'Lauwil',
#  'Biasca',
#  'Arogno',
#  'Kiesen',
#  'Weiach',
#  'Coeuve',
#  'Matran',
#  'Tuggen',
#  'Denens',
#  'Luzein',
#  'Saulcy',
#  'Toffen',
#  'Iffwil',
#  'Assens',
#  'Uezwil',
#  'Winkel',
#  'Bülach',
#  'Mathod',
#  'Möhlin',
#  'Grancy',
#  'Knonau',
#  'Chigny',
#  'Flawil',
#  'Uttwil',
#  'Heiden',
#  'Zizers',
#  'Rances',
#  'Malans',
#  'Sattel',
#  'Saanen',
#  'Ramsen',
#  'Zürich',
#  'Illgau',
#  'Glarus',
#  'Ebikon',
#  'Laupen',
#  'Losone',
#  'Aranno',
#  'Wauwil',
#  'Zernez',
#  'Fahrni',
#  'Airolo',
#  'Falera',
#  'Fehren',
#  'Orpund',
#  'Linden',
#  'Aadorf',
#  'Küblis',
#  'Törbel',
#  'Sorens',
#  'Salvan',
#  'Mühlau',
#  'Magden',
#  'Gsteig',
#  'Auswil',
#  'Vallon',
#  'Ropraz',
#  'Blauen',
#  'Riehen',
#  'Rorbas',
#  'Moudon',
#  'Inkwil',
#  'Abtwil',
#  'Jaberg',
#  'Zeihen',
#  'Coppet',
#  'Lugano',
#  'Ipsach',
#  'Lupfig',
#  'Lindau',
#  'Jongny',
#  'Sursee',
#  'Perroy',
#  'Sarnen',
#  'Wassen',
#  'Eschen',
#  'Prilly',
#  'Urdorf',
#  'Melide',
#  'Nendaz',
#  'Schwyz',
#  'Sufers',
#  'Gonten',
#  'Bister',
#  'Boudry',
#  'Schötz',
#  'Mauraz',
#  'Blenio',
#  'Naters',
#  'Cornol',
#  'Ursins',
#  'Lauerz',
#  'Villaz',
#  'Signau',
#  'Grüsch',
#  'Quinto',
#  'Paudex',
#  'Bavois',
#  'Termen',
#  'Muolen',
#  'Gurbrü',
#  'Stadel',
#  'Lucens',
#  'Weesen',
#  'Epsach',
#  'Kloten',
#  'Aclens',
#  'Bünzen',
#  'Soubey',
#  'Meyrin',
#  'Denges',
#  'Tübach',
#  'Gersau',
#  'Savosa',
#  'Yvorne',
#  'Volken',
#  'Ascona',
#  'Lommis',
#  'Neggio',
#  'Thônex',
#  'Dietwil',
#  'Anières',
#  'Zäziwil',
#  'Gordola',
#  'Baulmes',
#  'Sempach',
#  'Seuzach',
#  'Schänis',
#  'Bassins',
#  'Aubonne',
#  'Siselen',
#  'Zullwil',
#  'Sommeri',
#  'Dachsen',
#  'Juriens',
#  'Lungern',
#  'Gunzgen',
#  'Mammern',
#  'Wittnau',
#  'Rheinau',
#  'Moutier',
#  'Céligny',
#  'Itingen',
#  'Chénens',
#  'Lyssach',
#  'Bönigen',
#  'Lavigny',
#  'Goldach',
#  'Balgach',
#  'Autigny',
#  'Berolle',
#  'Nuvilly',
#  'Evolène',
#  'Nesslau',
#  'Quarten',
#  'Däniken',
#  'Zetzwil',
#  'Wolfwil',
#  'Savièse',
#  'Boulens',
#  'Gingins',
#  'Aarberg',
#  'Bürchen',
#  'Dinhard',
#  'Cologny',
#  'Pohlern',
#  'Chippis',
#  'Dornach',
#  'Vernate',
#  'Winznau',
#  'Origlio',
#  'Zuchwil',
#  'Saubraz',
#  'Le Lieu',
#  'Leutwil',
#  'Tecknau',
#  'Satigny',
#  'Concise',
#  'Sirnach',
#  'Veytaux',
#  'Grächen',
#  'Menznau',
#  'Braunau',
#  'Urnäsch',
#  'Fétigny',
#  'Silenen',
#  'Embrach',
#  'Gisikon',
#  'Ufhusen',
#  'Tägerig',
#  'La Tène',
#  'Alpnach',
#  'Sissach',
#  'Bannwil',
#  'Leytron',
#  'Vuadens',
#  'Maracon',
#  'Allaman',
#  'Fideris',
#  'Morcote',
#  'Vaulion',
#  'Treiten',
#  'Eschenz',
#  'Puidoux',
#  'Triesen',
#  'Zumikon',
#  'Wattwil',
#  'Tévenon',
#  'Blatten',
#  'Rümlang',
#  'Kerzers',
#  'Flüelen',
#  'Bercher',
#  'Pfäfers',
#  'Oberems',
#  'Luthern',
#  'Thürnen',
#  'Grolley',
#  'Mandach',
#  'Greppen',
#  'Riviera',
#  'Seeberg',
#  'Ballens',
#  'Schiers',
#  'Hagneck',
#  'Sisikon',
#  'Gurmels',
#  'Simplon',
#  'Ersigen',
#  'Berneck',
#  'Alpthal',
#  'Hundwil',
#  'La Praz',
#  'Eriswil',
#  'Yvonand',
#  'Vionnaz',
#  'Cornaux',
#  'Meinier',
#  'Troinex',
#  'Safnern',
#  'Calanca',
#  'Pfungen',
#  'Le Flon',
#  'S-chanf',
#  'Homburg',
#  'Mörigen',
#  'Riniken',
#  'Bioggio',
#  'Breggia',
#  'Samedan',
#  'Sumvitg',
#  'Giffers',
#  'Bursins',
#  'Staufen',
#  'Bottens',
#  'Steinen',
#  'Sorengo',
#  'Malters',
#  'Noville',
#  'Etziken',
#  'Zermatt',
#  'Sisseln',
#  'Rubigen',
#  'Nebikon',
#  'Finhaut',
#  'Sevelen',
#  'Neuheim',
#  'Ittigen',
#  'Payerne',
#  'Rueyres',
#  'Oberegg',
#  'Planken',
#  'Mönthal',
#  'Zurzach',
#  'Vitznau',
#  'Diegten',
#  'Locarno',
#  'Conthey',
#  'Biezwil',
#  'Chiasso',
#  'Tschugg',
#  'Lostorf',
#  'Therwil',
#  'Ferrera',
#  'Berikon',
#  'Bubikon',
#  'Zwingen',
#  'Flerden',
#  'Samnaun',
#  'Kaisten',
#  'Champoz',
#  'Grindel',
#  'Hallwil',
#  'Pleigne',
#  'Chalais',
#  'Bettens',
#  'Sullens',
#  'Begnins',
#  'Buchegg',
#  'Brunegg',
#  'Altikon',
#  'Rhäzüns',
#  'Evilard',
#  'Gamprin',
#  'Aristau',
#  'Servion',
#  'Bözberg',
#  'Hellsau',
#  'Au (SG)',
#  'Lotzwil',
#  'Balerna',
#  'Kesswil',
#  'Choulex',
#  'Grancia',
#  'Hittnau',
#  'Remigen',
#  'Farnern',
#  'Meyriez',
#  'Bellach',
#  'Marsens',
#  'Uttigen',
#  'Seengen',
#  'Huttwil',
#  'Vaulruz',
#  'Koblenz',
#  'Balzers',
#  'Sargans',
#  'Veyrier',
#  'Neerach',
#  'Homberg',
#  'Birrwil',
#  'Henniez',
#  'Genthod',
#  'Mosnang',
#  'Hüniken',
#  'Reitnau',
#  'Ballwil',
#  'Bissone',
#  'Givrins',
#  'Thurnen',
#  'Geltwil',
#  'Brütten',
#  'Belfaux',
#  'Olsberg',
#  'Dänikon',
#  'Liestal',
#  'Oberhof',
#  'Bonaduz',
#  'Wynigen',
#  'Caslano',
#  'Aarburg',
#  'Vacallo',
#  'Knutwil',
#  'Trimmis',
#  'Bättwil',
#  'Zufikon',
#  'Saxeten',
#  'Nottwil',
#  'Muzzano',
#  'Premier',
#  'Kallern',
#  'Opfikon',
#  'Savigny',
#  'Bettwil',
#  'Eglisau',
#  'Monthey',
#  'Buckten',
#  'Vernier',
#  'Mesocco',
#  'Albinen',
#  'Le Vaud',
#  'Rüegsau',
#  'Buttwil',
#  'Böckten',
#  'Eggiwil',
#  'Uitikon',
#  'Ruggell',
#  'Ergisch',
#  'Eschert',
#  'Lengwil',
#  'Gollion',
#  'Muralto',
#  'Penthaz',
#  'Habkern',
#  'Chessel',
#  'Selzach',
#  'Zunzgen',
#  'Lauenen',
#  'Démoret',
#  'Mirchel',
#  'Herdern',
#  'Versoix',
#  'Muttenz',
#  'Bennwil',
#  'Minusio',
#  'Gibloux',
#  'Dorénaz',
#  'Saillon',
#  'Muriaux',
#  'Dürnten',
#  'Nusshof',
#  'Thalwil',
#  'Herisau',
#  'Lufingen',
#  'Delémont',
#  'Henggart',
#  'Crémines',
#  'Rüttenen',
#  'Melchnau',
#  'Frutigen',
#  'Eischoll',
#  'Grandval',
#  'Chamblon',
#  'Thörigen',
#  'Oberthal',
#  'Villeret',
#  'Holziken',
#  'Erstfeld',
#  'Hölstein',
#  'Crissier',
#  'Willisau',
#  'Massagno',
#  'Lausanne',
#  'Kaufdorf',
#  'Linescio',
#  'Oeschgen',
#  'Siviriez',
#  'Plasselb',
#  'Vuarrens',
#  'Prangins',
#  'Boltigen',
#  'Klosters',
#  'Madulain',
#  'Molondin',
#  'Meikirch',
#  'Gampelen',
#  'Cudrefin',
#  'Attalens',
#  'Birrhard',
#  'Pfaffnau',
#  'Reutigen',
#  'Dottikon',
#  'Grandson',
#  'Burgdorf',
#  'Gurzelen',
#  'Val Mara',
#  'Müllheim',
#  'Lovatens',
#  'Rothrist',
#  'Eichberg',
#  'Scheuren',
#  'Boncourt',
#  'Daillens',
#  'Avenches',
#  'Brissago',
#  'Oppligen',
#  'Le Locle',
#  'Vechigen',
#  'Bussigny',
#  'Gachnang',
#  'Wildberg',
#  'Walchwil',
#  'Boniswil',
#  'Steinach',
#  'Leuggern',
#  'Sennwald',
#  'Bellwald',
#  'Röschenz',
#  'Treyvaux',
#  'Sachseln',
#  'Cureglia',
#  'Bettlach',
#  'Tramelan',
#  'Koppigen',
#  'Endingen',
#  'Schüpfen',
#  'Balsthal',
#  'Buchberg',
#  'Bellikon',
#  'Wiliberg',
#  'Hochdorf',
#  'Movelier',
#  'Eggenwil',
#  'Bussnang',
#  'Mülligen',
#  'Villigen',
#  'Courroux',
#  'Giornico',
#  'Eptingen',
#  'Rheineck',
#  'Ménières',
#  'Seftigen',
#  'Dardagny',
#  'Rüschegg',
#  'Develier',
#  'Hersberg',
#  'Oekingen',
#  'Les Bois',
#  'Bolligen',
#  'Neunforn',
#  'Würenlos',
#  'Zofingen',
#  'Dulliken',
#  'Attiswil',
#  'Fisibach',
#  'Montreux',
#  'Clarmont',
#  'Habsburg',
#  'Lostallo',
#  'Zeneggen',
#  'Novalles',
#  'Bretzwil',
#  'Champéry',
#  'Kienberg',
#  'Magliaso',
#  'Uerkheim',
#  'Vérossaz',
#  'Egolzwil',
#  'Coinsins',
#  'Tujetsch',
#  'Rebstein',
#  'Wil (SG)',
#  'La Roche',
#  'Dotzigen',
#  'Dietikon',
#  'Boussens',
#  'Burtigny',
#  'Chevilly',
#  'Stettlen',
#  'Erschwil',
#  'Kehrsatz',
#  'Brittnau',
#  'Isenthal',
#  'Bellmund',
#  'Schenkon',
#  'Dintikon',
#  'Boécourt',
#  'Kölliken',
#  'Pollegio',
#  'Boningen',
#  'Chéserex',
#  'Scharans',
#  'Provence',
#  'Subingen',
#  'Wolhusen',
#  'Chexbres',
#  'Büetigen',
#  'Rüfenach',
#  'Schelten',
#  'Adliswil',
#  'Corseaux',
#  'Dierikon',
#  'Martigny',
#  'Geuensee',
#  'Oberbalm',
#  'Dällikon',
#  'Schluein',
#  'Lüscherz',
#  'Aegerten',
#  'Puplinge',
#  'Menziken',
#  'Bäriswil',
#  'Orselina',
#  'Windisch',
#  'Verzasca',
#  'Därligen',
#  'Buchrain',
#  'Bursinel',
#  'Evionnaz',
#  'Canobbio',
#  'Bellevue',
#  'Speicher',
#  'Bedretto',
#  'Valbirse',
#  'Wuppenau',
#  'Dägerlen',
#  'Rohrbach',
#  'Hermance',
#  'Kappelen',
#  'La Sagne',
#  'Vulliens',
#  'Horriwil',
#  'Trimbach',
#  'Oberbipp',
#  'Safenwil',
#  'Orsières',
#  'Zollikon',
#  'Hemmiken',
#  'Neuenegg',
#  'Riedholz',
#  'Ermensee',
#  'Cartigny',
#  'Vernayaz',
#  'Cuarnens',
#  'Semsales',
#  'Heimberg',
#  'Tavannes',
#  'Pratteln',
#  'Salgesch',
#  'Mauensee',
#  'Obergoms',
#  'Ettiswil',
#  'Klingnau',
#  'Emmetten',
#  'Grenchen',
#  'Thayngen',
#  'Novaggio',
#  'Düdingen',
#  'Crassier',
#  'Russikon',
#  'Oberkulm',
#  'Lumnezia',
#  'Untervaz',
#  'Eclépens',
#  'Leuzigen',
#  'Duillier',
#  'Obfelden',
#  'Oberrüti',
#  'Egliswil',
#  'Altbüron',
#  'Wollerau',
#  'Lenzburg',
#  'Oltingen',
#  'Beringen',
#  'Mex (VD)',
#  'Laconnex',
#  'Biberist',
#  "L'Abbaye",
#  'Paradiso',
#  'Vallorbe',
#  'Triengen',
#  'Bofflens',
#  'Hedingen',
#  'Neuenhof',
#  'Goumoëns',
#  'Amriswil',
#  'Ossingen',
#  'Tenniken',
#  'Cossonay',
#  'Madiswil',
#  'Chevroux',
#  'Oberburg',
#  'Fribourg',
#  'Aefligen',
#  'Gruyères',
#  'Bournens',
#  'Hellikon',
#  'Günsberg',
#  'Salmsach',
#  'Cormoret',
#  'Saicourt',
#  'Suscévaz',
#  'Longirod',
#  'Ponthaux',
#  'Wil (ZH)',
#  'Hüttikon',
#  'Saas-Fee',
#  'Givisiez',
#  'Kallnach',
#  'Büttikon',
#  'Chamoson',
#  'Brislach',
#  'Schongau',
#  'Felsberg',
#  'Galgenen',
#  'La Rippe',
#  'Genolier',
#  'Valbroye',
#  'Presinge',
#  'Ettingen',
#  'Uebeschi',
#  'Bösingen',
#  'Arisdorf',
#  'Wallbach',
#  'Mellikon',
#  'Thundorf',
#  'Commugny',
#  'Hochwald',
#  'Liesberg',
#  'Küttigen',
#  'Mägenwil',
#  'Cortébert',
#  'Diemtigen',
#  'Echallens',
#  'Berg (TG)',
#  ...]

# %%
localities = set(df["Ortschaftsname"])
municipalities = set(df["Gemeindename"])
places = list(localities | municipalities | cantons)

# %%
len(localities), len(municipalities), len(localities | municipalities), len(places)
# Out:
# (3973, 2143, 4425, 4455)

# %% [markdown]
# Ortschaften und Gemeinden werden anhand folgender Regeln expandiert:
#
# 1. b. -> bei
# 2. S. -> Sogn, San, Sant', Sankt, Saint, Saint-
# 3. Prefixes: Au ZH, Au (SG), ... -> Au
# 4. Slash-getrennte Schreibweisen innerhalb von Prefixes: Brienz/Brinzauls -> Brienz, Brinzauls

# %%
places_aug = []
for place in places:
    # Expanding abbreviations
    if "b." in place:
        places_aug.append(place.replace("b.", "bei"))
    if "S. " in place:
        for subs in ["Sogn ", "San ", "Sant'", "Sankt ", "Saint ", "Saint-"]:
            places_aug.append(place.replace("S. ", subs))

    # Extract prefixes
    prefix = re.sub("(.*?) (?:(?:\(.*\)|[A-Z][A-Z]|b(?:\.|ei)|im).*)", r"\1", place)
    places_aug.append(prefix)

    # Does not handle suffixes
    if "/" in prefix:
        for subplace in prefix.split("/"):
            places_aug.append(subplace.strip())

places = list(set(places) | set(places_aug))

# Sort in reverse to match longer names first
places = sorted(places, key=lambda x: len(x), reverse=True)

# %%
places[:100]
# Out:
# ['Comunanza Cadenazzo/Monteceneri',
#  'Sankt Antonio (Val Morobbia)',
#  "Crête-à-l'Oeil (Les Agettes)",
#  'Saint-Antonio (Val Morobbia)',
#  'Saint Antonio (Val Morobbia)',
#  "Sant'Antonio (Val Morobbia)",
#  'Deisswil bei Münchenbuchsee',
#  'Sogn Antonio (Val Morobbia)',
#  'Flumserberg Tannenbodenalp',
#  'Weissenstein bei Solothurn',
#  'Schwendi im Weisstannental',
#  'Rudolfstetten-Friedlisberg',
#  'Aeschlen bei Oberdiessbach',
#  'Deisswil b. Münchenbuchsee',
#  'Röthenbach Herzogenbuchsee',
#  'San Antonio (Val Morobbia)',
#  'Weissenstein b. Solothurn',
#  'Finsterwald bei Entlebuch',
#  'Les Geneveys-sur-Coffrane',
#  'Fontaine Dessous (Liddes)',
#  'Niederried bei Interlaken',
#  'Aeschlen b. Oberdiessbach',
#  'Vuisternens-devant-Romont',
#  'S. Antonio (Val Morobbia)',
#  'Bleiken bei Oberdiessbach',
#  'Chavannes-sous-Orsonnens',
#  'Hettiswil bei Hindelbank',
#  'Reichenbach im Kandertal',
#  'Saint Carlo (Val Bavona)',
#  'Bangerten bei Dieterswil',
#  'Bleiken b. Oberdiessbach',
#  'Welschenrohr-Gänsbrunnen',
#  'Fontaine Dessus (Liddes)',
#  'Saint-Carlo (Val Bavona)',
#  'Guntershausen bei Aadorf',
#  'Les Valettes (Bovernier)',
#  'Finsterwald b. Entlebuch',
#  'Le Châtelard-près-Romont',
#  'Sankt Carlo (Val Bavona)',
#  'Walliswil bei Niederbipp',
#  'Niederried b. Interlaken',
#  'Petit Vichères (Liddes)',
#  'Chamoille (Sembrancher)',
#  'Guntershausen b. Aadorf',
#  'La Vernaz (Les Agettes)',
#  'Saint-Saphorin (Lavaux)',
#  'Feldbrunnen-St. Niklaus',
#  "Sant'Carlo (Val Bavona)",
#  'Schönenberg an der Thur',
#  'Schwarzenbach (Huttwil)',
#  'Corcelles-sur-Chavornay',
#  'Häusernmoos im Emmental',
#  'Saint Carlo (Poschiavo)',
#  'Reutlingen (Winterthur)',
#  'Hettiswil b. Hindelbank',
#  'Adlikon bei Andelfingen',
#  'Buch bei Kümmertshausen',
#  'Pont-de-la-Morge (Sion)',
#  'Basadingen-Schlattingen',
#  'Schafhausen im Emmental',
#  'Saint-Carlo (Poschiavo)',
#  'Oberried am Brienzersee',
#  'Zihlschlacht-Sitterdorf',
#  'Bangerten b. Dieterswil',
#  'Walliswil b. Niederbipp',
#  'Goldswil bei Interlaken',
#  'Les Moulins VS (Liddes)',
#  'Wildhaus-Alt St. Johann',
#  'Niederried bei Kallnach',
#  'Bertschikon (Gossau ZH)',
#  'Sankt Carlo (Poschiavo)',
#  'Schwenden im Diemtigtal',
#  'Radelfingen bei Aarberg',
#  'Sogn Carlo (Val Bavona)',
#  'Le Château-de-Ste-Croix',
#  'Stadel bei Niederglatt',
#  'Adlikon bei Regensdorf',
#  'Hergiswil bei Willisau',
#  'Weingarten-Kalthäusern',
#  'Neuhausen am Rheinfall',
#  'Sogn Carlo (Poschiavo)',
#  'San Carlo (Val Bavona)',
#  'Les Vérines (Chamoson)',
#  'Bütschwil-Ganterschwil',
#  'Ricketwil (Winterthur)',
#  'Fontaines-sur-Grandson',
#  'St-Saphorin-sur-Morges',
#  'Niederried b. Kallnach',
#  'Bönigen bei Interlaken',
#  'Essertines-sur-Yverdon',
#  'Oberhofen am Thunersee',
#  'Appenzell Enggenhütten',
#  'Villars-sous-Champvent',
#  'Erlenbach im Simmental',
#  "Les Sciernes-d'Albeuve",
#  'Santa Maria in Calanca',
#  'Châtel-sur-Montsalvens',
#  "Sant'Carlo (Poschiavo)",
#  'Röthenbach im Emmental',
#  'Flumserberg Tannenheim']

# %%
places[-100:]
# Out:
# ['Gals',
#  'Worb',
#  'Trey',
#  'Engi',
#  'Dino',
#  'Port',
#  'Riom',
#  'Croy',
#  'Avry',
#  'Etoy',
#  'Ftan',
#  'Aïre',
#  'Pura',
#  'Ayer',
#  'Oron',
#  'Riet',
#  'Vals',
#  'Watt',
#  'Noës',
#  'Giez',
#  'Praz',
#  'Visp',
#  'Lenk',
#  'Gohl',
#  'Jura',
#  'Vira',
#  'Vich',
#  'Präz',
#  'Alle',
#  'Arzo',
#  'Niva',
#  'Igis',
#  'Seon',
#  'Pizy',
#  'Gabi',
#  'Uors',
#  'Trun',
#  'Loco',
#  'Bänk',
#  'Grüt',
#  'Sutz',
#  'Thal',
#  'Thun',
#  'Pany',
#  'Höri',
#  'Burg',
#  'Mase',
#  'Arth',
#  'Laax',
#  'Lens',
#  'Pont',
#  'Osco',
#  'Orbe',
#  'Trub',
#  'Cama',
#  'Broc',
#  'Goms',
#  'Dorf',
#  'Rafz',
#  'Genf',
#  'Cham',
#  'Buix',
#  'Muri',
#  'Nods',
#  'Lohn',
#  'Trin',
#  'Jaun',
#  'Sins',
#  'Egg',
#  'Vex',
#  'Vnà',
#  'Auw',
#  'Oey',
#  'Sax',
#  'Lax',
#  'Ems',
#  'Asp',
#  'Zug',
#  'Fex',
#  'Mur',
#  'Rue',
#  'Vaz',
#  'Bex',
#  'Elm',
#  'Uri',
#  'Loc',
#  'Lai',
#  'Fey',
#  'Sur',
#  'Mex',
#  'Nax',
#  'Naz',
#  'Ins',
#  'Juf',
#  'Luc',
#  'Mon',
#  'Wil',
#  'Au',
#  'Lü',
#  'Gy']

# %% [markdown]
# Orte escapen und zu Regex-Konjunktion zusammensetzen.

# %%
places = [re.escape(place) for place in places]
loc_regex = f"\\b(?:{'|'.join(places)})\\b"
print(loc_regex)
# Out:
# \b(?:Comunanza\ Cadenazzo/Monteceneri|Sankt\ Antonio\ \(Val\ Morobbia\)|Crête\-à\-l'Oeil\ \(Les\ Agettes\)|Saint\-Antonio\ \(Val\ Morobbia\)|Saint\ Antonio\ \(Val\ Morobbia\)|Sant'Antonio\ \(Val\ Morobbia\)|Deisswil\ bei\ Münchenbuchsee|Sogn\ Antonio\ \(Val\ Morobbia\)|Flumserberg\ Tannenbodenalp|Weissenstein\ bei\ Solothurn|Schwendi\ im\ Weisstannental|Rudolfstetten\-Friedlisberg|Aeschlen\ bei\ Oberdiessbach|Deisswil\ b\.\ Münchenbuchsee|Röthenbach\ Herzogenbuchsee|San\ Antonio\ \(Val\ Morobbia\)|Weissenstein\ b\.\ Solothurn|Finsterwald\ bei\ Entlebuch|Les\ Geneveys\-sur\-Coffrane|Fontaine\ Dessous\ \(Liddes\)|Niederried\ bei\ Interlaken|Aeschlen\ b\.\ Oberdiessbach|Vuisternens\-devant\-Romont|S\.\ Antonio\ \(Val\ Morobbia\)|Bleiken\ bei\ Oberdiessbach|Chavannes\-sous\-Orsonnens|Hettiswil\ bei\ Hindelbank|Reichenbach\ im\ Kandertal|Saint\ Carlo\ \(Val\ Bavona\)|Bangerten\ bei\ Dieterswil|Bleiken\ b\.\ Oberdiessbach|Welschenrohr\-Gänsbrunnen|Fontaine\ Dessus\ \(Liddes\)|Saint\-Carlo\ \(Val\ Bavona\)|Guntershausen\ bei\ Aadorf|Les\ Valettes\ \(Bovernier\)|Finsterwald\ b\.\ Entlebuch|Le\ Châtelard\-près\-Romont|Sankt\ Carlo\ \(Val\ Bavona\)|Walliswil\ bei\ Niederbipp|Niederried\ b\.\ Interlaken|Petit\ Vichères\ \(Liddes\)|Chamoille\ \(Sembrancher\)|Guntershausen\ b\.\ Aadorf|La\ Vernaz\ \(Les\ Agettes\)|Saint\-Saphorin\ \(Lavaux\)|Feldbrunnen\-St\.\ Niklaus|Sant'Carlo\ \(Val\ Bavona\)|Schönenberg\ an\ der\ Thur|Schwarzenbach\ \(Huttwil\)|Corcelles\-sur\-Chavornay|Häusernmoos\ im\ Emmental|Saint\ Carlo\ \(Poschiavo\)|Reutlingen\ \(Winterthur\)|Hettiswil\ b\.\ Hindelbank|Adlikon\ bei\ Andelfingen|Buch\ bei\ Kümmertshausen|Pont\-de\-la\-Morge\ \(Sion\)|Basadingen\-Schlattingen|Schafhausen\ im\ Emmental|Saint\-Carlo\ \(Poschiavo\)|Oberried\ am\ Brienzersee|Zihlschlacht\-Sitterdorf|Bangerten\ b\.\ Dieterswil|Walliswil\ b\.\ Niederbipp|Goldswil\ bei\ Interlaken|Les\ Moulins\ VS\ \(Liddes\)|Wildhaus\-Alt\ St\.\ Johann|Niederried\ bei\ Kallnach|Bertschikon\ \(Gossau\ ZH\)|Sankt\ Carlo\ \(Poschiavo\)|Schwenden\ im\ Diemtigtal|Radelfingen\ bei\ Aarberg|Sogn\ Carlo\ \(Val\ Bavona\)|Le\ Château\-de\-Ste\-Croix|Stadel\ bei\ Niederglatt|Adlikon\ bei\ Regensdorf|Hergiswil\ bei\ Willisau|Weingarten\-Kalthäusern|Neuhausen\ am\ Rheinfall|Sogn\ Carlo\ \(Poschiavo\)|San\ Carlo\ \(Val\ Bavona\)|Les\ Vérines\ \(Chamoson\)|Bütschwil\-Ganterschwil|Ricketwil\ \(Winterthur\)|Fontaines\-sur\-Grandson|St\-Saphorin\-sur\-Morges|Niederried\ b\.\ Kallnach|Bönigen\ bei\ Interlaken|Essertines\-sur\-Yverdon|Oberhofen\ am\ Thunersee|Appenzell\ Enggenhütten|Villars\-sous\-Champvent|Erlenbach\ im\ Simmental|Les\ Sciernes\-d'Albeuve|Santa\ Maria\ in\ Calanca|Châtel\-sur\-Montsalvens|Sant'Carlo\ \(Poschiavo\)|Röthenbach\ im\ Emmental|Flumserberg\ Tannenheim|Lüsslingen\-Nennigkofen|Appenzell\ Ausserrhoden|Buch\ b\.\ Kümmertshausen|Valeyres\-sous\-Montagny|Corcelles\-près\-Concise|Guntershausen\ bei\ Berg|Appenzell\ Meistersrüte|Sta\.\ Maria\ Val\ Müstair|Goldswil\ b\.\ Interlaken|Radelfingen\ b\.\ Aarberg|Adlikon\ b\.\ Andelfingen|Corcelles\-près\-Payerne|Fontannen\ bei\ Wolhusen|Appenzell\ Eggerstanden|Montagne\-de\-Courtelary|Schwändi\ bei\ Schwanden|La\ Garde\ \(Sembrancher\)|Grangettes\-près\-Romont|Montagny\-près\-Yverdon|Hergiswil\ b\.\ Willisau|Blonay\ \-\ Saint\-Légier|Essert\-sous\-Champvent|Lüterkofen\-Ichertswil|Le\ Crêt\-près\-Semsales|Villars\-sur\-Fontenais|Montagne\-de\-Sonvilier|Appenzell\ Innerrhoden|Schwändi\ b\.\ Schwanden|Mannenbach\-Salenstein|Oulens\-sous\-Echallens|Schwanden\ \(Sigriswil\)|Hagenwil\ bei\ Amriswil|Hasliberg\ Wasserwendi|Hermetschwil\-Staffeln|S\.\ Carlo\ \(Val\ Bavona\)|Cheseaux\-sur\-Lausanne|Montaubion\-Chardonney|Guntershausen\ b\.\ Berg|Mézery\-près\-Donneloye|Niederwangen\ bei\ Bern|San\ Carlo\ \(Poschiavo\)|Hofstetten\ bei\ Brienz|Schwanden\ im\ Emmental|Fontannen\ b\.\ Wolhusen|La\ Chaux\-des\-Breuleux|Affoltern\ im\ Emmental|Dettighofen\ \(Lengwil\)|Treytorrens\ \(Payerne\)|Saint\-Barthélemy\ \(VD\)|Allmendingen\ bei\ Ber ...

# %% [markdown]
# Export

# %%
# Modify path depending on working directory of Jupyter environment
with open("../resources/locs_within_orgs_regex.txt", "w") as f:
    f.write(loc_regex)
